# %% [markdown]
# <h1> Notebook utilising inital dataset</h1>
# <p><i>Through my preentation, I discuss how after evaluating my model results, I found the model exceeded my expectations significantly.
# Upon looking at the dataset, I found some of the JPEG images had clear visual impairments in the 'forged' category, making it
# signficiantly easier for the model to detect fraud from original. This Notebook shows that inital dataset workflow. I use the alternaitve notebook to show how my models handle more detailed/high-definition images and impacts the overall model performance. As I discuss, my results in both notebooks follow similar trends regarding which models/techniques were more/less successful. I seperated the notebooks for readability and the workflow remains the same in both</i> </p>

# %%
'''
Code base for COMP7710 *Note utilised tutorial code and
some AI generated code throughout assignment (AI was mostly
used for pre-processing, visualisation and correctly implementing class methods)
I will anotate where, why and explain the code :)
'''

#Step 1: imports
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset, random_split
from PIL import Image, ImageChops, ImageEnhance
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np


import os
import time

# %%
#Utilises Google Drive for loading the data into notebook
# import files from google drive and unzip files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Uncomment if needing to remove and reset solution
#!rm -r COMP7710_FP_Dataset
# !rm -r COMP7710_FP_Dataset_2000/

# %%
# !cp /content/drive/MyDrive/COMP7710/COMP7710_FP_Dataset.zip ./

# %%
#unzip my zip-file to be local in my Google Colab environment
# !rm -rf './COMP7710_FP_Dataset'
# !unzip '/content/COMP7710_FP_Dataset.zip'
# !rm -rf './ELA_Dataset'
data_dir = './COMP7710_FP_Dataset'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: COMP7710_FP_Dataset/Original/2349.jpg
#   inflating: COMP7710_FP_Dataset/Original/235.jpg
#   inflating: COMP7710_FP_Dataset/Original/2350.jpg
#   inflating: COMP7710_FP_Dataset/Original/2351.jpg
#   inflating: COMP7710_FP_Dataset/Original/2352.jpg
#   inflating: COMP7710_FP_Dataset/Original/2353.jpg
#   inflating: COMP7710_FP_Dataset/Original/2354.jpg
#   inflating: COMP7710_FP_Dataset/Original/2355.jpg
#   inflating: COMP7710_FP_Dataset/Original/2356.jpg
#   inflating: COMP7710_FP_Dataset/Original/2357.jpg
#   inflating: COMP7710_FP_Dataset/Original/2358.jpg
#   inflating: COMP7710_FP_Dataset/Original/2359.jpg
#   inflating: COMP7710_FP_Dataset/Original/236.jpg
#   inflating: COMP7710_FP_Dataset/Original/2360.jpg
#   inflating: COMP7710_FP_Dataset/Original/2361.jpg
#   inflating: COMP7710_FP_Dataset/Original/2362.jpg
#   inflating: COMP7710_FP_Dataset/Original/2363.jpg
#   inflating: COMP7710_FP_Dataset/Original/2364.jpg
#   inflating: COMP7710_FP_Dataset/Original/2365.jpg
#   inflating: COMP7710_FP_Dataset/Original/2366.jpg
#   inflating: COMP7710_FP_Dataset/Original/2367.jpg
#   inflating: COMP7710_FP_Dataset/Original/2368.jpg
#   inflating: COMP7710_FP_Dataset/Original/2369.jpg
#   inflating: COMP7710_FP_Dataset/Original/237.jpg
#   inflating: COMP7710_FP_Dataset/Original/2370.jpg
#   inflating: COMP7710_FP_Dataset/Original/2371.jpg
#   inflating: COMP7710_FP_Dataset/Original/2372.jpg
#   inflating: COMP7710_FP_Dataset/Original/2373.jpg
#   inflating: COMP7710_FP_Dataset/Original/2374.jpg
#   inflating: COMP7710_FP_Dataset/Original/2375.jpg
#   inflating: COMP7710_FP_Dataset/Original/2376.jpg
#   inflating: COMP7710_FP_Dataset/Original/2377.jpg
#   inflating: COMP7710_FP_Dataset/Original/2378.jpg
#   inflating: COMP7710_FP_Dataset/Original/2379.jpg
#   inflating: COMP7710_FP_Dataset/Original/238.jpg
#   inflating: COMP7710_FP_Dataset/Original/2380.jpg
#   inflating: COMP7710_FP_Dataset/Original/2381.jpg
#   inflating: COMP7710_FP_Dataset/Original/2382.jpg
#   inflating: COMP7710_FP_Dataset/Original/2383.jpg
#   inflating: COMP7710_FP_Dataset/Original/2384.jpg
#   inflating: COMP7710_FP_Dataset/Original/2385.jpg
#   inflating: COMP7710_FP_Dataset/Original/2386.jpg
#   inflating: COMP7710_FP_Dataset/Original/2387.jpg
#   inflating: COMP7710_FP_Dataset/Original/2388.jpg
#   inflating: COMP7710_FP_Dataset/Original/2389.jpg
#   inflating: COMP7710_FP_Dataset/Original/239.jpg
#   inflating: COMP7710_FP_Dataset/Original/2390.jpg
#   inflating: COMP7710_FP_Dataset/Original/2391.jpg
#   inflating: COMP7710_FP_Dataset/Original/2392.jpg
#   inflating: COMP7710_FP_Dataset/Original/2393.jpg
#   inflating: COMP7710_FP_Dataset/Original/2394.jpg
#   inflating: COMP7710_FP_Dataset/Original/2395.jpg
#   inflating: COMP7710_FP_Dataset/Original/2396.jpg
#   inflating: COMP7710_FP_Dataset/Original/2397.jpg
#   inflating: COMP7710_FP_Dataset/Original/2398.jpg
#   inflating: COMP7710_FP_Dataset/Original/2399.jpg
#   inflating: COMP7710_FP_Dataset/Original/24.jpg
#   inflating: COMP7710_FP_Dataset/Original/240.jpg
#   inflating: COMP7710_FP_Dataset/Original/2400.jpg
#   inflating: COMP7710_FP_Dataset/Original/2401.jpg
#   inflating: COMP7710_FP_Dataset/Original/2402.jpg
#   inflating: COMP7710_FP_Dataset/Original/2403.jpg
#   inflating: COMP7710_FP_Dataset/Original/2404.jpg
#   inflating: COMP7710_FP_Dataset/Original/2405.jpg
#   inflating: COMP7710_FP_Dataset/Original/2406.jpg
#   inflating: COMP7710_FP_Dataset/Original/2407.jpg
#   inflating: COMP7710_FP_Dataset/Original/2408.jpg
#   inflating: COMP7710_FP_Dataset/Original/2409.jpg
#   inflating: COMP7710_FP_Dataset/Original/241.jpg
#   inflating: COMP7710_FP_Dataset/Original/2410.jpg
#   inflating: COMP7710_FP_Dataset/Original/2411.jpg
#   inflating: COMP7710_FP_Dataset/Original/2412.jpg
#   inflating: COMP7710_FP_Dataset/Original/2413.jpg
#   inflating: COMP7710_FP_Dataset/Original/2414.jpg
#   inflating: COMP7710_FP_Dataset/Original/2415.jpg
#   inflating: COMP7710_FP_Dataset/Original/2416.jpg
#   inflating: COMP7710_FP_Dataset/Original/2417.jpg
#   inflating: COMP7710_FP_Dataset/Original/2418.jpg
#   inflating: COMP7710_FP_Dataset/Original/2419.jpg
#   inflating: COMP7710_FP_Dataset/Original/242.jpg
#   inflating: COMP7710_FP_Dataset/Original/2420.JPG
#   inflating: COMP7710_FP_Dataset/Original/2421.jpg
#   inflating: COMP7710_FP_Dataset/Original/2422.jpg
#   inflating: COMP7710_FP_Dataset/Original/2423.jpg
#   inflating: COMP7710_FP_Dataset/Original/2424.jpg
#   inflating: COMP7710_FP_Dataset/Original/2425.jpg
#   inflating: COMP7710_FP_Dataset/Original/2426.jpg
#   inflating: COMP7710_FP_Dataset/Original/2427.JPG
#   inflating: COMP7710_FP_Dataset/Original/2428.jpg
#   inflating: COMP7710_FP_Dataset/Original/2429.jpg
#   inflating: COMP7710_FP_Dataset/Original/243.jpg
#   inflating: COMP7710_FP_Dataset/Original/2430.jpg
#   inflating: COMP7710_FP_Dataset/Original/2431.jpg
#   inflating: COMP7710_FP_Dataset/Original/2432.jpg
#   inflating: COMP7710_FP_Dataset/Original/2433.jpg
#   inflating: COMP7710_FP_Dataset/Original/2434.jpg
#   inflating: COMP7710_FP_Dataset/Original/2435.jpg
#   inflating: COMP7710_FP_Dataset/Original/2436.jpg
#   inflating: COMP7710_FP_Dataset/Original/2437.jpg
#   inflating: COMP7710_FP_Dataset/Original/2438.jpg
#   inflating: COMP7710_FP_Dataset/Original/2439.jpg
#   inflating: COMP7710_FP_Dataset/Original/244.jpg
#   inflating: COMP7710_FP_Dataset/Original/2440.jpg
#   inflating: COMP7710_FP_Dataset/Original/2441.jpg
#   inflating: COMP7710_FP_Dataset/Original/2442.jpg
#   inflating: COMP7710_FP_Dataset/Original/2443.jpg
#   inflating: COMP7710_FP_Dataset/Original/2444.jpg
#   inflating: COMP7710_FP_Dataset/Original/2445.jpg
#   inflating: COMP7710_FP_Dataset/Original/2446.jpg
#   inflating: COMP7710_FP_Dataset/Original/2447.JPG
#   inflating: COMP7710_FP_Dataset/Original/2448.jpg
#   inflating: COMP7710_FP_Dataset/Original/2449.JPG
#   inflating: COMP7710_FP_Dataset/Original/245.jpg
#   inflating: COMP7710_FP_Dataset/Original/2450.jpg
#   inflating: COMP7710_FP_Dataset/Original/2451.jpg
#   inflating: COMP7710_FP_Dataset/Original/2452.jpg
#   inflating: COMP7710_FP_Dataset/Original/2453.jpg
#   inflating: COMP7710_FP_Dataset/Original/2454.jpg
#   inflating: COMP7710_FP_Dataset/Original/2455.jpg
#   inflating: COMP7710_FP_Dataset/Original/2456.jpg
#   inflating: COMP7710_FP_Dataset/Original/2457.jpg
#   inflating: COMP7710_FP_Dataset/Original/2458.jpg
#   inflating: COMP7710_FP_Dataset/Original/2459.jpg
#   inflating: COMP7710_FP_Dataset/Original/246.jpg
#   inflating: COMP7710_FP_Dataset/Original/2460.jpg
#   inflating: COMP7710_FP_Dataset/Original/2461.jpg
#   inflating: COMP7710_FP_Dataset/Original/2462.jpg
#   inflating: COMP7710_FP_Dataset/Original/2463.jpg
#   inflating: COMP7710_FP_Dataset/Original/2464.jpg
#   inflating: COMP7710_FP_Dataset/Original/2465.jpg
#   inflating: COMP7710_FP_Dataset/Original/2466.jpg
#   inflating: COMP7710_FP_Dataset/Original/2467.jpg
#   inflating: COMP7710_FP_Dataset/Original/2468.jpg
#   inflating: COMP7710_FP_Dataset/Original/2469.jpg
#   inflating: COMP7710_FP_Dataset/Original/247.jpg
#   inflating: COMP7710_FP_Dataset/Original/2470.jpg
#   inflating: COMP7710_FP_Dataset/Original/2471.jpg
#   inflating: COMP7710_FP_Dataset/Original/2472.jpg
#   inflating: COMP7710_FP_Dataset/Original/2473.jpg
#   inflating: COMP7710_FP_Dataset/Original/2474.jpg
#   inflating: COMP7710_FP_Dataset/Original/2475.jpg
#   inflating: COMP7710_FP_Dataset/Original/2476.jpg
#   inflating: COMP7710_FP_Dataset/Original/2477.jpg
#   inflating: COMP7710_FP_Dataset/Original/2478.jpg
#   inflating: COMP7710_FP_Dataset/Original/2479.jpg
#   inflating: COMP7710_FP_Dataset/Original/248.jpg
#   inflating: COMP7710_FP_Dataset/Original/2480.jpg
#   inflating: COMP7710_FP_Dataset/Original/2481.jpg
#   inflating: COMP7710_FP_Dataset/Original/2482.jpg
#   inflating: COMP7710_FP_Dataset/Original/2483.jpg
#   inflating: COMP7710_FP_Dataset/Original/2484.jpg
#   inflating: COMP7710_FP_Dataset/Original/2485.jpg
#   inflating: COMP7710_FP_Dataset/Original/2486.jpg
#   inflating: COMP7710_FP_Dataset/Original/2487.jpg
#   inflating: COMP7710_FP_Dataset/Original/2488.jpg
#   inflating: COMP7710_FP_Dataset/Original/2489.jpg
#   inflating: COMP7710_FP_Dataset/Original/249.jpg
#   inflating: COMP7710_FP_Dataset/Original/2490.jpg
#   inflating: COMP7710_FP_Dataset/Original/2491.jpg
#   inflating: COMP7710_FP_Dataset/Original/2492.jpg
#   inflating: COMP7710_FP_Dataset/Original/2493.jpg
#   inflating: COMP7710_FP_Dataset/Original/2494.jpg
#   inflating: COMP7710_FP_Dataset/Original/2495.jpg
#   inflating: COMP7710_FP_Dataset/Original/2496.jpg
#   inflating: COMP7710_FP_Dataset/Original/2497.jpg
#   inflating: COMP7710_FP_Dataset/Original/2498.jpg
#   inflating: COMP7710_FP_Dataset/Original/2499.jpg
#   inflating: COMP7710_FP_Dataset/Original/25.jpg
#   inflating: COMP7710_FP_Dataset/Original/250.jpg
#   inflating: COMP7710_FP_Dataset/Original/2500.jpg
#   inflating: COMP7710_FP_Dataset/Original/2501.jpg
#   inflating: COMP7710_FP_Dataset/Original/2502.jpg
#   inflating: COMP7710_FP_Dataset/Original/2503.jpg
#   inflating: COMP7710_FP_Dataset/Original/2504.jpg
#   inflating: COMP7710_FP_Dataset/Original/2505.jpg
#   inflating: COMP7710_FP_Dataset/Original/2506.jpg
#   inflating: COMP7710_FP_Dataset/Original/2507.jpg
#   inflating: COMP7710_FP_Dataset/Original/2508.jpg
#   inflating: COMP7710_FP_Dataset/Original/2509.jpg
#   inflating: COMP7710_FP_Dataset/Original/251.jpg
#   inflating: COMP7710_FP_Dataset/Original/2510.jpg
#   inflating: COMP7710_FP_Dataset/Original/2511.jpg
#   inflating: COMP7710_FP_Dataset/Original/2512.jpg
#   inflating: COMP7710_FP_Dataset/Original/2513.jpg
#   inflating: COMP7710_FP_Dataset/Original/2514.jpg
#   inflating: COMP7710_FP_Dataset/Original/2515.jpg
#   inflating: COMP7710_FP_Dataset/Original/2516.jpg
#   inflating: COMP7710_FP_Dataset/Original/2517.jpg
#   inflating: COMP7710_FP_Dataset/Original/2518.jpg
#   inflating: COMP7710_FP_Dataset/Original/2519.jpg
#   inflating: COMP7710_FP_Dataset/Original/252.jpg
#   inflating: COMP7710_FP_Dataset/Original/2520.jpg
#   inflating: COMP7710_FP_Dataset/Original/2521.jpg
#   inflating: COMP7710_FP_Dataset/Original/2522.jpg
#   inflating: COMP7710_FP_Dataset/Original/2523.jpg
#   inflating: COMP7710_FP_Dataset/Original/2524.jpg
#   inflating: COMP7710_FP_Dataset/Original/2525.jpg
#   inflating: COMP7710_FP_Dataset/Original/2526.jpg
#   inflating: COMP7710_FP_Dataset/Original/2527.jpg
#   inflating: COMP7710_FP_Dataset/Original/2528.jpg
#   inflating: COMP7710_FP_Dataset/Original/2529.jpg
#   inflating: COMP7710_FP_Dataset/Original/253.jpg
#   inflating: COMP7710_FP_Dataset/Original/2530.jpg
#   inflating: COMP7710_FP_Dataset/Original/2531.jpg
#   inflating: COMP7710_FP_Dataset/Original/2532.jpg
#   inflating: COMP7710_FP_Dataset/Original/2533.jpg
#   inflating: COMP7710_FP_Dataset/Original/2534.jpg
#   inflating: COMP7710_FP_Dataset/Original/2535.jpg
#   inflating: COMP7710_FP_Dataset/Original/2536.jpg
#   inflating: COMP7710_FP_Dataset/Original/2537.jpg
#   inflating: COMP7710_FP_Dataset/Original/2538.jpg
#   inflating: COMP7710_FP_Dataset/Original/2539.jpg
#   inflating: COMP7710_FP_Dataset/Original/254.jpg
#   inflating: COMP7710_FP_Dataset/Original/2540.jpg
#   inflating: COMP7710_FP_Dataset/Original/2541.jpg
#   inflating: COMP7710_FP_Dataset/Original/2542.jpg
#   inflating: COMP7710_FP_Dataset/Original/2543.jpg
#   inflating: COMP7710_FP_Dataset/Original/2544.jpg
#   inflating: COMP7710_FP_Dataset/Original/2545.jpg
#   inflating: COMP7710_FP_Dataset/Original/2546.jpg
#   inflating: COMP7710_FP_Dataset/Original/2547.jpg
#   inflating: COMP7710_FP_Dataset/Original/2548.jpg
#   inflating: COMP7710_FP_Dataset/Original/2549.jpg
#   inflating: COMP7710_FP_Dataset/Original/255.jpg
#   inflating: COMP7710_FP_Dataset/Original/2550.jpg
#   inflating: COMP7710_FP_Dataset/Original/2551.jpg
#   inflating: COMP7710_FP_Dataset/Original/2552.jpg
#   inflating: COMP7710_FP_Dataset/Original/2553.jpg
#   inflating: COMP7710_FP_Dataset/Original/2554.jpg
#   inflating: COMP7710_FP_Dataset/Original/2555.jpg
#   inflating: COMP7710_FP_Dataset/Original/2556.jpg
#   inflating: COMP7710_FP_Dataset/Original/2557.jpg
#   inflating: COMP7710_FP_Dataset/Original/2558.jpg
#   inflating: COMP7710_FP_Dataset/Original/2559.jpg
#   inflating: COMP7710_FP_Dataset/Original/256.jpg
#   inflating: COMP7710_FP_Dataset/Original/2560.jpg
#   inflating: COMP7710_FP_Dataset/Original/2561.jpg
#   inflating: COMP7710_FP_Dataset/Original/2562.jpg
#   inflating: COMP7710_FP_Dataset/Original/2563.jpg
#   inflating: COMP7710_FP_Dataset/Original/2564.jpg
#   inflating: COMP7710_FP_Dataset/Original/2565.jpg
#   inflating: COMP7710_FP_Dataset/Original/2566.jpg
#   inflating: COMP7710_FP_Dataset/Original/2567.jpg
#   inflating: COMP7710_FP_Dataset/Original/2568.jpg
#   inflating: COMP7710_FP_Dataset/Original/2569.jpg
#   inflating: COMP7710_FP_Dataset/Original/257.jpg
#   inflating: COMP7710_FP_Dataset/Original/2570.jpg
#   inflating: COMP7710_FP_Dataset/Original/2571.jpg
#   inflating: COMP7710_FP_Dataset/Original/2572.jpg
#   inflating: COMP7710_FP_Dataset/Original/2573.jpg
#   inflating: COMP7710_FP_Dataset/Original/2574.jpg
#   inflating: COMP7710_FP_Dataset/Original/2575.jpg
#   inflating: COMP7710_FP_Dataset/Original/2576.jpg
#   inflating: COMP7710_FP_Dataset/Original/2577.jpg
#   inflating: COMP7710_FP_Dataset/Original/2578.jpg
#   inflating: COMP7710_FP_Dataset/Original/2579.jpg
#   inflating: COMP7710_FP_Dataset/Original/258.jpg
#   inflating: COMP7710_FP_Dataset/Original/2580.jpg
#   inflating: COMP7710_FP_Dataset/Original/2581.jpg
#   inflating: COMP7710_FP_Dataset/Original/2582.jpg
#   inflating: COMP7710_FP_Dataset/Original/2583.jpg
#   inflating: COMP7710_FP_Dataset/Original/2584.jpg
#   inflating: COMP7710_FP_Dataset/Original/2585.jpg
#   inflating: COMP7710_FP_Dataset/Original/2586.jpg
#   inflating: COMP7710_FP_Dataset/Original/2587.jpg
#   inflating: COMP7710_FP_Dataset/Original/2588.jpg
#   inflating: COMP7710_FP_Dataset/Original/2589.jpg
#   inflating: COMP7710_FP_Dataset/Original/259.jpg
#   inflating: COMP7710_FP_Dataset/Original/2590.jpg
#   inflating: COMP7710_FP_Dataset/Original/2591.jpg
#   inflating: COMP7710_FP_Dataset/Original/2592.jpg
#   inflating: COMP7710_FP_Dataset/Original/2593.jpg
#   inflating: COMP7710_FP_Dataset/Original/2594.jpg
#   inflating: COMP7710_FP_Dataset/Original/2595.jpg
#   inflating: COMP7710_FP_Dataset/Original/2596.jpg
#   inflating: COMP7710_FP_Dataset/Original/2597.jpg
#   inflating: COMP7710_FP_Dataset/Original/2598.jpg
#   inflating: COMP7710_FP_Dataset/Original/2599.jpg
#   inflating: COMP7710_FP_Dataset/Original/26.jpg
#   inflating: COMP7710_FP_Dataset/Original/260.jpg
#   inflating: COMP7710_FP_Dataset/Original/2600.jpg
#   inflating: COMP7710_FP_Dataset/Original/2601.jpg
#   inflating: COMP7710_FP_Dataset/Original/2602.jpg
#   inflating: COMP7710_FP_Dataset/Original/2603.jpg
#   inflating: COMP7710_FP_Dataset/Original/2604.jpg
#   inflating: COMP7710_FP_Dataset/Original/2605.jpg
#   inflating: COMP7710_FP_Dataset/Original/2606.jpg
#   inflating: COMP7710_FP_Dataset/Original/2607.jpg
#   inflating: COMP7710_FP_Dataset/Original/2608.jpg
#   inflating: COMP7710_FP_Dataset/Original/2609.jpg
#   inflating: COMP7710_FP_Dataset/Original/261.jpg
#   inflating: COMP7710_FP_Dataset/Original/2610.jpg
#   inflating: COMP7710_FP_Dataset/Original/2611.jpg
#   inflating: COMP7710_FP_Dataset/Original/2612.jpg
#   inflating: COMP7710_FP_Dataset/Original/2613.jpg
#   inflating: COMP7710_FP_Dataset/Original/2614.jpg
#   inflating: COMP7710_FP_Dataset/Original/2615.jpg
#   inflating: COMP7710_FP_Dataset/Original/2616.jpg
#   inflating: COMP7710_FP_Dataset/Original/2617.jpg
#   inflating: COMP7710_FP_Dataset/Original/2618.jpg
#   inflating: COMP7710_FP_Dataset/Original/2619.jpg
#   inflating: COMP7710_FP_Dataset/Original/262.jpg
#   inflating: COMP7710_FP_Dataset/Original/2620.jpg
#   inflating: COMP7710_FP_Dataset/Original/2621.jpg
#   inflating: COMP7710_FP_Dataset/Original/2622.jpg
#   inflating: COMP7710_FP_Dataset/Original/2623.jpg
#   inflating: COMP7710_FP_Dataset/Original/2624.jpg
#   inflating: COMP7710_FP_Dataset/Original/2625.jpg
#   inflating: COMP7710_FP_Dataset/Original/2626.jpg
#   inflating: COMP7710_FP_Dataset/Original/2627.jpg
#   inflating: COMP7710_FP_Dataset/Original/2628.jpg
#   inflating: COMP7710_FP_Dataset/Original/2629.jpg
#   inflating: COMP7710_FP_Dataset/Original/263.jpg
#   inflating: COMP7710_FP_Dataset/Original/2630.jpg
#   inflating: COMP7710_FP_Dataset/Original/2631.jpg
#   inflating: COMP7710_FP_Dataset/Original/2632.jpg
#   inflating: COMP7710_FP_Dataset/Original/2633.jpg
#   inflating: COMP7710_FP_Dataset/Original/2634.jpg
#   inflating: COMP7710_FP_Dataset/Original/2635.jpg
#   inflating: COMP7710_FP_Dataset/Original/2636.jpg
#   inflating: COMP7710_FP_Dataset/Original/2637.jpg
#   inflating: COMP7710_FP_Dataset/Original/2638.jpg
#   inflating: COMP7710_FP_Dataset/Original/2639.jpg
#   inflating: COMP7710_FP_Dataset/Original/264.jpg
#   inflating: COMP7710_FP_Dataset/Original/2640.jpg
#   inflating: COMP7710_FP_Dataset/Original/2641.jpg
#   inflating: COMP7710_FP_Dataset/Original/2642.jpg
#   inflating: COMP7710_FP_Dataset/Original/2643.jpg
#   inflating: COMP7710_FP_Dataset/Original/2644.jpg
#   inflating: COMP7710_FP_Dataset/Original/2645.jpg
#   inflating: COMP7710_FP_Dataset/Original/2646.jpg
#   inflating: COMP7710_FP_Dataset/Original/2647.jpg
#   inflating: COMP7710_FP_Dataset/Original/2648.jpg
#   inflating: COMP7710_FP_Dataset/Original/2649.jpg
#   inflating: COMP7710_FP_Dataset/Original/265.jpg
#   inflating: COMP7710_FP_Dataset/Original/2650.jpg
#   inflating: COMP7710_FP_Dataset/Original/2651.jpg
#   inflating: COMP7710_FP_Dataset/Original/2652.jpg
#   inflating: COMP7710_FP_Dataset/Original/2653.jpg
#   inflating: COMP7710_FP_Dataset/Original/2654.jpg
#   inflating: COMP7710_FP_Dataset/Original/2655.jpg
#   inflating: COMP7710_FP_Dataset/Original/2656.jpg
#   inflating: COMP7710_FP_Dataset/Original/2657.jpg
#   inflating: COMP7710_FP_Dataset/Original/2658.jpg
#   inflating: COMP7710_FP_Dataset/Original/2659.jpg
#   inflating: COMP7710_FP_Dataset/Original/266.jpg
#   inflating: COMP7710_FP_Dataset/Original/2660.jpg
#   inflating: COMP7710_FP_Dataset/Original/2661.jpg
#   inflating: COMP7710_FP_Dataset/Original/2662.jpg
#   inflating: COMP7710_FP_Dataset/Original/2663.jpg
#   inflating: COMP7710_FP_Dataset/Original/2664.jpg
#   inflating: COMP7710_FP_Dataset/Original/2665.jpg
#   inflating: COMP7710_FP_Dataset/Original/2666.jpg
#   inflating: COMP7710_FP_Dataset/Original/2667.jpg
#   inflating: COMP7710_FP_Dataset/Original/2668.jpg
#   inflating: COMP7710_FP_Dataset/Original/2669.jpg
#   inflating: COMP7710_FP_Dataset/Original/267.jpg
#   inflating: COMP7710_FP_Dataset/Original/2670.jpg
#   inflating: COMP7710_FP_Dataset/Original/2671.jpg
#   inflating: COMP7710_FP_Dataset/Original/2672.jpg
#   inflating: COMP7710_FP_Dataset/Original/2673.jpg
#   inflating: COMP7710_FP_Dataset/Original/2674.jpg
#   inflating: COMP7710_FP_Dataset/Original/2675.jpg
#   inflating: COMP7710_FP_Dataset/Original/2676.jpg
#   inflating: COMP7710_FP_Dataset/Original/2677.jpg
#   inflating: COMP7710_FP_Dataset/Original/2678.jpg
#   inflating: COMP7710_FP_Dataset/Original/2679.jpg
#   inflating: COMP7710_FP_Dataset/Original/268.jpg
#   inflating: COMP7710_FP_Dataset/Original/2680.jpg
#   inflating: COMP7710_FP_Dataset/Original/2681.jpg
#   inflating: COMP7710_FP_Dataset/Original/2682.jpg
#   inflating: COMP7710_FP_Dataset/Original/2683.jpg
#   inflating: COMP7710_FP_Dataset/Original/2684.jpg
#   inflating: COMP7710_FP_Dataset/Original/2685.jpg
#   inflating: COMP7710_FP_Dataset/Original/2686.jpg
#   inflating: COMP7710_FP_Dataset/Original/2687.jpg
#   inflating: COMP7710_FP_Dataset/Original/2688.jpg
#   inflating: COMP7710_FP_Dataset/Original/2689.jpg
#   inflating: COMP7710_FP_Dataset/Original/269.jpg
#   inflating: COMP7710_FP_Dataset/Original/2690.jpg
#   inflating: COMP7710_FP_Dataset/Original/2691.jpg
#   inflating: COMP7710_FP_Dataset/Original/2692.jpg
#   inflating: COMP7710_FP_Dataset/Original/2693.jpg
#   inflating: COMP7710_FP_Dataset/Original/2694.jpg
#   inflating: COMP7710_FP_Dataset/Original/2695.jpg
#   inflating: COMP7710_FP_Dataset/Original/2696.jpg
#   inflating: COMP7710_FP_Dataset/Original/2697.jpg
#   inflating: COMP7710_FP_Dataset/Original/2698.jpg
#   inflating: COMP7710_FP_Dataset/Original/2699.jpg
#   inflating: COMP7710_FP_Dataset/Original/27.jpg
#   inflating: COMP7710_FP_Dataset/Original/270.jpg
#   inflating: COMP7710_FP_Dataset/Original/2700.jpg
#   inflating: COMP7710_FP_Dataset/Original/2701.jpg
#   inflating: COMP7710_FP_Dataset/Original/2702.jpg
#   inflating: COMP7710_FP_Dataset/Original/2703.jpg
#   inflating: COMP7710_FP_Dataset/Original/2704.jpg
#   inflating: COMP7710_FP_Dataset/Original/2705.jpg
#   inflating: COMP7710_FP_Dataset/Original/2706.jpg
#   inflating: COMP7710_FP_Dataset/Original/2707.jpg
#   inflating: COMP7710_FP_Dataset/Original/2708.jpg
#   inflating: COMP7710_FP_Dataset/Original/2709.jpg
#   inflating: COMP7710_FP_Dataset/Original/271.jpg
#   inflating: COMP7710_FP_Dataset/Original/2710.jpg
#   inflating: COMP7710_FP_Dataset/Original/2711.jpg
#   inflating: COMP7710_FP_Dataset/Original/2712.jpg
#   inflating: COMP7710_FP_Dataset/Original/2713.jpg
#   inflating: COMP7710_FP_Dataset/Original/2714.jpg
#   inflating: COMP7710_FP_Dataset/Original/2715.jpg
#   inflating: COMP7710_FP_Dataset/Original/2716.jpg
#   inflating: COMP7710_FP_Dataset/Original/2717.jpg
#   inflating: COMP7710_FP_Dataset/Original/2718.jpg
#   inflating: COMP7710_FP_Dataset/Original/2719.jpg
#   inflating: COMP7710_FP_Dataset/Original/272.jpg
#   inflating: COMP7710_FP_Dataset/Original/2720.jpg
#   inflating: COMP7710_FP_Dataset/Original/2721.jpg
#   inflating: COMP7710_FP_Dataset/Original/2722.jpg
#   inflating: COMP7710_FP_Dataset/Original/2723.jpg
#   inflating: COMP7710_FP_Dataset/Original/2724.jpg
#   inflating: COMP7710_FP_Dataset/Original/2725.jpg
#   inflating: COMP7710_FP_Dataset/Original/2726.jpg
#   inflating: COMP7710_FP_Dataset/Original/2727.jpg
#   inflating: COMP7710_FP_Dataset/Original/2728.jpg
#   inflating: COMP7710_FP_Dataset/Original/2729.jpg
#   inflating: COMP7710_FP_Dataset/Original/273.jpg
#   inflating: COMP7710_FP_Dataset/Original/2730.jpg
#   inflating: COMP7710_FP_Dataset/Original/2731.jpg
#   inflating: COMP7710_FP_Dataset/Original/2732.jpg
#   inflating: COMP7710_FP_Dataset/Original/2733.jpg
#   inflating: COMP7710_FP_Dataset/Original/2734.jpg
#   inflating: COMP7710_FP_Dataset/Original/2735.jpg
#   inflating: COMP7710_FP_Dataset/Original/2736.jpg
#   inflating: COMP7710_FP_Dataset/Original/2737.jpg
#   inflating: COMP7710_FP_Dataset/Original/2738.jpg
#   inflating: COMP7710_FP_Dataset/Original/2739.jpg
#   inflating: COMP7710_FP_Dataset/Original/274.jpg
#   inflating: COMP7710_FP_Dataset/Original/2740.jpg
#   inflating: COMP7710_FP_Dataset/Original/2741.jpg
#   inflating: COMP7710_FP_Dataset/Original/2742.jpg
#   inflating: COMP7710_FP_Dataset/Original/2743.jpg
#   inflating: COMP7710_FP_Dataset/Original/2744.jpg
#   inflating: COMP7710_FP_Dataset/Original/2745.jpg
#   inflating: COMP7710_FP_Dataset/Original/2746.jpg
#   inflating: COMP7710_FP_Dataset/Original/2747.jpg
#   inflating: COMP7710_FP_Dataset/Original/2748.jpg
#   inflating: COMP7710_FP_Dataset/Original/2749.jpg
#   inflating: COMP7710_FP_Dataset/Original/275.jpg
#   inflating: COMP7710_FP_Dataset/Original/2750.jpg
#   inflating: COMP7710_FP_Dataset/Original/2751.jpg
#   inflating: COMP7710_FP_Dataset/Original/2752.jpg
#   inflating: COMP7710_FP_Dataset/Original/2753.jpg
#   inflating: COMP7710_FP_Dataset/Original/2754.jpg
#   inflating: COMP7710_FP_Dataset/Original/2755.jpg
#   inflating: COMP7710_FP_Dataset/Original/2756.jpg
#   inflating: COMP7710_FP_Dataset/Original/2757.jpg
#   inflating: COMP7710_FP_Dataset/Original/2758.jpg
#   inflating: COMP7710_FP_Dataset/Original/2759.jpg
#   inflating: COMP7710_FP_Dataset/Original/276.jpg
#   inflating: COMP7710_FP_Dataset/Original/2760.jpg
#   inflating: COMP7710_FP_Dataset/Original/2761.jpg
#   inflating: COMP7710_FP_Dataset/Original/2762.jpg
#   inflating: COMP7710_FP_Dataset/Original/2763.jpg
#   inflating: COMP7710_FP_Dataset/Original/2764.jpg
#   inflating: COMP7710_FP_Dataset/Original/2765.jpg
#   inflating: COMP7710_FP_Dataset/Original/2766.jpg
#   inflating: COMP7710_FP_Dataset/Original/2767.jpg
#   inflating: COMP7710_FP_Dataset/Original/2768.jpg
#   inflating: COMP7710_FP_Dataset/Original/2769.jpg
#   inflating: COMP7710_FP_Dataset/Original/277.jpg
#   inflating: COMP7710_FP_Dataset/Original/2770.jpg
#   inflating: COMP7710_FP_Dataset/Original/2771.jpg
#   inflating: COMP7710_FP_Dataset/Original/2772.jpg
#   inflating: COMP7710_FP_Dataset/Original/2773.jpg
#   inflating: COMP7710_FP_Dataset/Original/2774.jpg
#   inflating: COMP7710_FP_Dataset/Original/2775.jpg
#   inflating: COMP7710_FP_Dataset/Original/2776.jpg
#   inflating: COMP7710_FP_Dataset/Original/2777.jpg
#   inflating: COMP7710_FP_Dataset/Original/2778.jpg
#   inflating: COMP7710_FP_Dataset/Original/2779.jpg
#   inflating: COMP7710_FP_Dataset/Original/278.jpg
#   inflating: COMP7710_FP_Dataset/Original/2780.jpg
#   inflating: COMP7710_FP_Dataset/Original/2781.jpg
#   inflating: COMP7710_FP_Dataset/Original/2782.jpg
#   inflating: COMP7710_FP_Dataset/Original/2783.jpg
#   inflating: COMP7710_FP_Dataset/Original/2784.jpg
#   inflating: COMP7710_FP_Dataset/Original/2785.jpg
#   inflating: COMP7710_FP_Dataset/Original/2786.jpg
#   inflating: COMP7710_FP_Dataset/Original/2787.jpg
#   inflating: COMP7710_FP_Dataset/Original/2788.jpg
#   inflating: COMP7710_FP_Dataset/Original/2789.jpg
#   inflating: COMP7710_FP_Dataset/Original/279.jpg
#   inflating: COMP7710_FP_Dataset/Original/2790.jpg
#   inflating: COMP7710_FP_Dataset/Original/2791.jpg
#   inflating: COMP7710_FP_Dataset/Original/2792.jpg
#   inflating: COMP7710_FP_Dataset/Original/2793.jpg
#   inflating: COMP7710_FP_Dataset/Original/2794.jpg
#   inflating: COMP7710_FP_Dataset/Original/2795.jpg
#   inflating: COMP7710_FP_Dataset/Original/2796.jpg
#   inflating: COMP7710_FP_Dataset/Original/2797.jpg
#   inflating: COMP7710_FP_Dataset/Original/2798.jpg
#   inflating: COMP7710_FP_Dataset/Original/2799.jpg
#   inflating: COMP7710_FP_Dataset/Original/28.jpg
#   inflating: COMP7710_FP_Dataset/Original/280.jpg
#   inflating: COMP7710_FP_Dataset/Original/2800.jpg
#   inflating: COMP7710_FP_Dataset/Original/2801.jpg
#   inflating: COMP7710_FP_Dataset/Original/2802.jpg
#   inflating: COMP7710_FP_Dataset/Original/2803.jpg
#   inflating: COMP7710_FP_Dataset/Original/2804.jpg
#   inflating: COMP7710_FP_Dataset/Original/2805.jpg
#   inflating: COMP7710_FP_Dataset/Original/2806.jpg
#   inflating: COMP7710_FP_Dataset/Original/2807.jpg
#   inflating: COMP7710_FP_Dataset/Original/2808.jpg
#   inflating: COMP7710_FP_Dataset/Original/2809.jpg
#   inflating: COMP7710_FP_Dataset/Original/281.jpg
#   inflating: COMP7710_FP_Dataset/Original/2810.jpg
#   inflating: COMP7710_FP_Dataset/Original/2811.jpg
#   inflating: COMP7710_FP_Dataset/Original/2812.jpg
#   inflating: COMP7710_FP_Dataset/Original/2813.jpg
#   inflating: COMP7710_FP_Dataset/Original/2814.jpg
#   inflating: COMP7710_FP_Dataset/Original/2815.jpg
#   inflating: COMP7710_FP_Dataset/Original/2816.jpg
#   inflating: COMP7710_FP_Dataset/Original/2817.jpg
#   inflating: COMP7710_FP_Dataset/Original/2818.jpg
#   inflating: COMP7710_FP_Dataset/Original/2819.jpg
#   inflating: COMP7710_FP_Dataset/Original/282.jpg
#   inflating: COMP7710_FP_Dataset/Original/2820.jpg
#   inflating: COMP7710_FP_Dataset/Original/2821.jpg
#   inflating: COMP7710_FP_Dataset/Original/2822.jpg
#   inflating: COMP7710_FP_Dataset/Original/2823.jpg
#   inflating: COMP7710_FP_Dataset/Original/2824.jpg
#   inflating: COMP7710_FP_Dataset/Original/2825.jpg
#   inflating: COMP7710_FP_Dataset/Original/2826.jpg
#   inflating: COMP7710_FP_Dataset/Original/2827.jpg
#   inflating: COMP7710_FP_Dataset/Original/2828.jpg
#   inflating: COMP7710_FP_Dataset/Original/2829.jpg
#   inflating: COMP7710_FP_Dataset/Original/283.jpg
#   inflating: COMP7710_FP_Dataset/Original/2830.jpg
#   inflating: COMP7710_FP_Dataset/Original/2831.jpg
#   inflating: COMP7710_FP_Dataset/Original/2832.jpg
#   inflating: COMP7710_FP_Dataset/Original/2833.jpg
#   inflating: COMP7710_FP_Dataset/Original/2834.jpg
#   inflating: COMP7710_FP_Dataset/Original/2835.jpg
#   inflating: COMP7710_FP_Dataset/Original/2836.jpg
#   inflating: COMP7710_FP_Dataset/Original/2837.jpg
#   inflating: COMP7710_FP_Dataset/Original/2838.jpg
#   inflating: COMP7710_FP_Dataset/Original/2839.jpg
#   inflating: COMP7710_FP_Dataset/Original/284.jpg
#   inflating: COMP7710_FP_Dataset/Original/2840.jpg
#   inflating: COMP7710_FP_Dataset/Original/2841.jpg
#   inflating: COMP7710_FP_Dataset/Original/2842.jpg
#   inflating: COMP7710_FP_Dataset/Original/2843.jpg
#   inflating: COMP7710_FP_Dataset/Original/2844.jpg
#   inflating: COMP7710_FP_Dataset/Original/2845.jpg
#   inflating: COMP7710_FP_Dataset/Original/2846.jpg
#   inflating: COMP7710_FP_Dataset/Original/2847.jpg
#   inflating: COMP7710_FP_Dataset/Original/2848.jpg
#   inflating: COMP7710_FP_Dataset/Original/2849.jpg
#   inflating: COMP7710_FP_Dataset/Original/285.jpg
#   inflating: COMP7710_FP_Dataset/Original/2850.jpg
#   inflating: COMP7710_FP_Dataset/Original/2851.jpg
#   inflating: COMP7710_FP_Dataset/Original/2852.jpg
#   inflating: COMP7710_FP_Dataset/Original/2853.jpg
#   inflating: COMP7710_FP_Dataset/Original/2854.jpg
#   inflating: COMP7710_FP_Dataset/Original/2855.jpg
#   inflating: COMP7710_FP_Dataset/Original/2856.jpg
#   inflating: COMP7710_FP_Dataset/Original/2857.jpg
#   inflating: COMP7710_FP_Dataset/Original/2858.jpg
#   inflating: COMP7710_FP_Dataset/Original/2859.jpg
#   inflating: COMP7710_FP_Dataset/Original/286.jpg
#   inflating: COMP7710_FP_Dataset/Original/2860.jpg
#   inflating: COMP7710_FP_Dataset/Original/2861.jpg
#   inflating: COMP7710_FP_Dataset/Original/2862.jpg
#   inflating: COMP7710_FP_Dataset/Original/2863.jpg
#   inflating: COMP7710_FP_Dataset/Original/2864.jpg
#   inflating: COMP7710_FP_Dataset/Original/2865.jpg
#   inflating: COMP7710_FP_Dataset/Original/2866.jpg
#   inflating: COMP7710_FP_Dataset/Original/2867.jpg
#   inflating: COMP7710_FP_Dataset/Original/2868.jpg
#   inflating: COMP7710_FP_Dataset/Original/2869.jpg
#   inflating: COMP7710_FP_Dataset/Original/287.jpg
#   inflating: COMP7710_FP_Dataset/Original/2870.jpg
#   inflating: COMP7710_FP_Dataset/Original/2871.jpg
#   inflating: COMP7710_FP_Dataset/Original/2872.jpg
#   inflating: COMP7710_FP_Dataset/Original/2873.jpg
#   inflating: COMP7710_FP_Dataset/Original/2874.jpg
#   inflating: COMP7710_FP_Dataset/Original/2875.jpg
#   inflating: COMP7710_FP_Dataset/Original/2876.jpg
#   inflating: COMP7710_FP_Dataset/Original/2877.jpg
#   inflating: COMP7710_FP_Dataset/Original/2878.jpg
#   inflating: COMP7710_FP_Dataset/Original/2879.jpg
#   inflating: COMP7710_FP_Dataset/Original/288.jpg
#   inflating: COMP7710_FP_Dataset/Original/2880.jpg
#   inflating: COMP7710_FP_Dataset/Original/2881.jpg
#   inflating: COMP7710_FP_Dataset/Original/2882.jpg
#   inflating: COMP7710_FP_Dataset/Original/2883.jpg
#   inflating: COMP7710_FP_Dataset/Original/2884.jpg
#   inflating: COMP7710_FP_Dataset/Original/2885.jpg
#   inflating: COMP7710_FP_Dataset/Original/2886.jpg
#   inflating: COMP7710_FP_Dataset/Original/2887.jpg
#   inflating: COMP7710_FP_Dataset/Original/2888.jpg
#   inflating: COMP7710_FP_Dataset/Original/2889.jpg
#   inflating: COMP7710_FP_Dataset/Original/289.jpg
#   inflating: COMP7710_FP_Dataset/Original/2890.jpg
#   inflating: COMP7710_FP_Dataset/Original/2891.jpg
#   inflating: COMP7710_FP_Dataset/Original/2892.jpg
#   inflating: COMP7710_FP_Dataset/Original/2893.jpg
#   inflating: COMP7710_FP_Dataset/Original/2894.jpg
#   inflating: COMP7710_FP_Dataset/Original/2895.jpg
#   inflating: COMP7710_FP_Dataset/Original/2896.jpg
#   inflating: COMP7710_FP_Dataset/Original/2897.jpg
#   inflating: COMP7710_FP_Dataset/Original/2898.jpg
#   inflating: COMP7710_FP_Dataset/Original/2899.jpg
#   inflating: COMP7710_FP_Dataset/Original/29.jpg
#   inflating: COMP7710_FP_Dataset/Original/290.jpg
#   inflating: COMP7710_FP_Dataset/Original/2900.jpg
#   inflating: COMP7710_FP_Dataset/Original/2901.jpg
#   inflating: COMP7710_FP_Dataset/Original/2902.jpg
#   inflating: COMP7710_FP_Dataset/Original/2903.jpg
#   inflating: COMP7710_FP_Dataset/Original/2904.jpg
#   inflating: COMP7710_FP_Dataset/Original/2905.jpg
#   inflating: COMP7710_FP_Dataset/Original/2906.jpg
#   inflating: COMP7710_FP_Dataset/Original/2907.jpg
#   inflating: COMP7710_FP_Dataset/Original/2908.jpg
#   inflating: COMP7710_FP_Dataset/Original/2909.jpg
#   inflating: COMP7710_FP_Dataset/Original/291.jpg
#   inflating: COMP7710_FP_Dataset/Original/2910.jpg
#   inflating: COMP7710_FP_Dataset/Original/2911.jpg
#   inflating: COMP7710_FP_Dataset/Original/2912.JPG
#   inflating: COMP7710_FP_Dataset/Original/2913.JPG
#   inflating: COMP7710_FP_Dataset/Original/2914.jpg
#   inflating: COMP7710_FP_Dataset/Original/2915.jpg
#   inflating: COMP7710_FP_Dataset/Original/2916.JPG
#   inflating: COMP7710_FP_Dataset/Original/2917.jpg
#   inflating: COMP7710_FP_Dataset/Original/2918.JPG
#   inflating: COMP7710_FP_Dataset/Original/2919.jpg
#   inflating: COMP7710_FP_Dataset/Original/292.jpg
#   inflating: COMP7710_FP_Dataset/Original/2920.JPG
#   inflating: COMP7710_FP_Dataset/Original/2921.jpg
#   inflating: COMP7710_FP_Dataset/Original/2922.JPG
#   inflating: COMP7710_FP_Dataset/Original/2923.jpg
#   inflating: COMP7710_FP_Dataset/Original/2924.JPG
#   inflating: COMP7710_FP_Dataset/Original/2925.JPG
#   inflating: COMP7710_FP_Dataset/Original/2926.JPG
#   inflating: COMP7710_FP_Dataset/Original/2927.jpg
#   inflating: COMP7710_FP_Dataset/Original/2928.JPG
#   inflating: COMP7710_FP_Dataset/Original/2929.JPG
#   inflating: COMP7710_FP_Dataset/Original/293.jpg
#   inflating: COMP7710_FP_Dataset/Original/2930.jpg
#   inflating: COMP7710_FP_Dataset/Original/2931.JPG
#   inflating: COMP7710_FP_Dataset/Original/2932.jpg
#   inflating: COMP7710_FP_Dataset/Original/2933.jpg
#   inflating: COMP7710_FP_Dataset/Original/2934.JPG
#   inflating: COMP7710_FP_Dataset/Original/2935.jpg
#   inflating: COMP7710_FP_Dataset/Original/2936.JPG
#   inflating: COMP7710_FP_Dataset/Original/2937.jpg
#   inflating: COMP7710_FP_Dataset/Original/2938.JPG
#   inflating: COMP7710_FP_Dataset/Original/2939.jpg
#   inflating: COMP7710_FP_Dataset/Original/294.jpg
#   inflating: COMP7710_FP_Dataset/Original/2940.JPG
#   inflating: COMP7710_FP_Dataset/Original/2941.jpg
#   inflating: COMP7710_FP_Dataset/Original/2942.JPG
#   inflating: COMP7710_FP_Dataset/Original/2943.jpg
#   inflating: COMP7710_FP_Dataset/Original/2944.jpg
#   inflating: COMP7710_FP_Dataset/Original/2945.JPG
#   inflating: COMP7710_FP_Dataset/Original/2946.jpg
#   inflating: COMP7710_FP_Dataset/Original/2947.JPG
#   inflating: COMP7710_FP_Dataset/Original/2948.jpg
#   inflating: COMP7710_FP_Dataset/Original/2949.JPG
#   inflating: COMP7710_FP_Dataset/Original/295.jpg
#   inflating: COMP7710_FP_Dataset/Original/2950.jpg
#   inflating: COMP7710_FP_Dataset/Original/2951.JPG
#   inflating: COMP7710_FP_Dataset/Original/2952.jpg
#   inflating: COMP7710_FP_Dataset/Original/2953.JPG
#   inflating: COMP7710_FP_Dataset/Original/2954.jpg
#   inflating: COMP7710_FP_Dataset/Original/2955.jpg
#   inflating: COMP7710_FP_Dataset/Original/2956.JPG
#   inflating: COMP7710_FP_Dataset/Original/2957.JPG
#   inflating: COMP7710_FP_Dataset/Original/2958.JPG
#   inflating: COMP7710_FP_Dataset/Original/2959.JPG
#   inflating: COMP7710_FP_Dataset/Original/296.jpg
#   inflating: COMP7710_FP_Dataset/Original/2960.JPG
#   inflating: COMP7710_FP_Dataset/Original/2961.JPG
#   inflating: COMP7710_FP_Dataset/Original/2962.jpg
#   inflating: COMP7710_FP_Dataset/Original/2963.JPG
#   inflating: COMP7710_FP_Dataset/Original/2964.jpg
#   inflating: COMP7710_FP_Dataset/Original/2965.jpg
#   inflating: COMP7710_FP_Dataset/Original/2966.jpg
#   inflating: COMP7710_FP_Dataset/Original/2967.jpg
#   inflating: COMP7710_FP_Dataset/Original/2968.JPG
#   inflating: COMP7710_FP_Dataset/Original/2969.jpg
#   inflating: COMP7710_FP_Dataset/Original/297.jpg
#   inflating: COMP7710_FP_Dataset/Original/2970.JPG
#   inflating: COMP7710_FP_Dataset/Original/2971.jpg
#   inflating: COMP7710_FP_Dataset/Original/2972.JPG
#   inflating: COMP7710_FP_Dataset/Original/2973.jpg
#   inflating: COMP7710_FP_Dataset/Original/2974.JPG
#   inflating: COMP7710_FP_Dataset/Original/2975.jpg
#   inflating: COMP7710_FP_Dataset/Original/2976.jpg
#   inflating: COMP7710_FP_Dataset/Original/2977.jpg
#   inflating: COMP7710_FP_Dataset/Original/2978.JPG
#   inflating: COMP7710_FP_Dataset/Original/2979.jpg
#   inflating: COMP7710_FP_Dataset/Original/298.jpg
#   inflating: COMP7710_FP_Dataset/Original/2980.JPG
#   inflating: COMP7710_FP_Dataset/Original/2981.jpg
#   inflating: COMP7710_FP_Dataset/Original/2982.JPG
#   inflating: COMP7710_FP_Dataset/Original/2983.JPG
#   inflating: COMP7710_FP_Dataset/Original/2984.jpg
#   inflating: COMP7710_FP_Dataset/Original/2985.JPG
#   inflating: COMP7710_FP_Dataset/Original/2986.jpg
#   inflating: COMP7710_FP_Dataset/Original/2987.jpg
#   inflating: COMP7710_FP_Dataset/Original/2988.JPG
#   inflating: COMP7710_FP_Dataset/Original/2989.jpg
#   inflating: COMP7710_FP_Dataset/Original/299.jpg
#   inflating: COMP7710_FP_Dataset/Original/2990.JPG
#   inflating: COMP7710_FP_Dataset/Original/2991.jpg
#   inflating: COMP7710_FP_Dataset/Original/2992.JPG
#   inflating: COMP7710_FP_Dataset/Original/2993.jpg
#   inflating: COMP7710_FP_Dataset/Original/2994.JPG
#   inflating: COMP7710_FP_Dataset/Original/2995.jpg
#   inflating: COMP7710_FP_Dataset/Original/2996.JPG
#   inflating: COMP7710_FP_Dataset/Original/2997.jpg
#   inflating: COMP7710_FP_Dataset/Original/2998.jpg
#   inflating: COMP7710_FP_Dataset/Original/2999.JPG
#   inflating: COMP7710_FP_Dataset/Original/3.tif
#   inflating: COMP7710_FP_Dataset/Original/30.jpg
#   inflating: COMP7710_FP_Dataset/Original/300.jpg
#   inflating: COMP7710_FP_Dataset/Original/3000.jpg
#   inflating: COMP7710_FP_Dataset/Original/3001.JPG
#   inflating: COMP7710_FP_Dataset/Original/3002.jpg
#   inflating: COMP7710_FP_Dataset/Original/3003.JPG
#   inflating: COMP7710_FP_Dataset/Original/3004.jpg
#   inflating: COMP7710_FP_Dataset/Original/3005.JPG
#   inflating: COMP7710_FP_Dataset/Original/3006.jpg
#   inflating: COMP7710_FP_Dataset/Original/3007.JPG
#   inflating: COMP7710_FP_Dataset/Original/3008.jpg
#   inflating: COMP7710_FP_Dataset/Original/3009.jpg
#   inflating: COMP7710_FP_Dataset/Original/301.jpg
#   inflating: COMP7710_FP_Dataset/Original/3010.JPG
#   inflating: COMP7710_FP_Dataset/Original/3011.JPG
#   inflating: COMP7710_FP_Dataset/Original/3012.jpg
#   inflating: COMP7710_FP_Dataset/Original/3013.JPG
#   inflating: COMP7710_FP_Dataset/Original/3014.JPG
#   inflating: COMP7710_FP_Dataset/Original/3015.JPG
#   inflating: COMP7710_FP_Dataset/Original/3016.jpg
#   inflating: COMP7710_FP_Dataset/Original/3017.JPG
#   inflating: COMP7710_FP_Dataset/Original/3018.JPG
#   inflating: COMP7710_FP_Dataset/Original/3019.JPG
#   inflating: COMP7710_FP_Dataset/Original/302.jpg
#   inflating: COMP7710_FP_Dataset/Original/3020.jpg
#   inflating: COMP7710_FP_Dataset/Original/3021.jpg
#   inflating: COMP7710_FP_Dataset/Original/3022.JPG
#   inflating: COMP7710_FP_Dataset/Original/3023.JPG
#   inflating: COMP7710_FP_Dataset/Original/3024.jpg
#   inflating: COMP7710_FP_Dataset/Original/3025.JPG
#   inflating: COMP7710_FP_Dataset/Original/3026.jpg
#   inflating: COMP7710_FP_Dataset/Original/3027.JPG
#   inflating: COMP7710_FP_Dataset/Original/3028.jpg
#   inflating: COMP7710_FP_Dataset/Original/3029.JPG
#   inflating: COMP7710_FP_Dataset/Original/303.jpg
#   inflating: COMP7710_FP_Dataset/Original/3030.jpg
#   inflating: COMP7710_FP_Dataset/Original/3031.JPG
#   inflating: COMP7710_FP_Dataset/Original/3032.jpg
#   inflating: COMP7710_FP_Dataset/Original/3033.jpg
#   inflating: COMP7710_FP_Dataset/Original/3034.jpg
#   inflating: COMP7710_FP_Dataset/Original/3035.JPG
#   inflating: COMP7710_FP_Dataset/Original/3036.jpg
#   inflating: COMP7710_FP_Dataset/Original/3037.JPG
#   inflating: COMP7710_FP_Dataset/Original/3038.jpg
#   inflating: COMP7710_FP_Dataset/Original/3039.jpg
#   inflating: COMP7710_FP_Dataset/Original/304.jpg
#   inflating: COMP7710_FP_Dataset/Original/3040.JPG
#   inflating: COMP7710_FP_Dataset/Original/3041.jpg
#   inflating: COMP7710_FP_Dataset/Original/3042.jpg
#   inflating: COMP7710_FP_Dataset/Original/3043.jpg
#   inflating: COMP7710_FP_Dataset/Original/3044.JPG
#   inflating: COMP7710_FP_Dataset/Original/3045.JPG
#   inflating: COMP7710_FP_Dataset/Original/3046.JPG
#   inflating: COMP7710_FP_Dataset/Original/3047.jpg
#   inflating: COMP7710_FP_Dataset/Original/3048.JPG
#   inflating: COMP7710_FP_Dataset/Original/3049.JPG
#   inflating: COMP7710_FP_Dataset/Original/305.jpg
#   inflating: COMP7710_FP_Dataset/Original/3050.jpg
#   inflating: COMP7710_FP_Dataset/Original/3051.JPG
#   inflating: COMP7710_FP_Dataset/Original/3052.jpg
#   inflating: COMP7710_FP_Dataset/Original/3053.JPG
#   inflating: COMP7710_FP_Dataset/Original/3054.jpg
#   inflating: COMP7710_FP_Dataset/Original/3055.jpg
#   inflating: COMP7710_FP_Dataset/Original/3056.jpg
#   inflating: COMP7710_FP_Dataset/Original/3057.JPG
#   inflating: COMP7710_FP_Dataset/Original/3058.jpg
#   inflating: COMP7710_FP_Dataset/Original/3059.jpg
#   inflating: COMP7710_FP_Dataset/Original/306.jpg
#   inflating: COMP7710_FP_Dataset/Original/3060.JPG
#   inflating: COMP7710_FP_Dataset/Original/3061.jpg
#   inflating: COMP7710_FP_Dataset/Original/3062.JPG
#   inflating: COMP7710_FP_Dataset/Original/3063.jpg
#   inflating: COMP7710_FP_Dataset/Original/3064.JPG
#   inflating: COMP7710_FP_Dataset/Original/3065.jpg
#   inflating: COMP7710_FP_Dataset/Original/3066.jpg
#   inflating: COMP7710_FP_Dataset/Original/3067.jpg
#   inflating: COMP7710_FP_Dataset/Original/3068.JPG
#   inflating: COMP7710_FP_Dataset/Original/3069.jpg
#   inflating: COMP7710_FP_Dataset/Original/307.jpg
#   inflating: COMP7710_FP_Dataset/Original/3070.jpg
#   inflating: COMP7710_FP_Dataset/Original/3071.JPG
#   inflating: COMP7710_FP_Dataset/Original/3072.jpg
#   inflating: COMP7710_FP_Dataset/Original/3073.jpg
#   inflating: COMP7710_FP_Dataset/Original/3074.JPG
#   inflating: COMP7710_FP_Dataset/Original/3075.jpg
#   inflating: COMP7710_FP_Dataset/Original/3076.jpg
#   inflating: COMP7710_FP_Dataset/Original/3077.JPG
#   inflating: COMP7710_FP_Dataset/Original/3078.jpg
#   inflating: COMP7710_FP_Dataset/Original/3079.JPG
#   inflating: COMP7710_FP_Dataset/Original/308.jpg
#   inflating: COMP7710_FP_Dataset/Original/3080.JPG
#   inflating: COMP7710_FP_Dataset/Original/3081.jpg
#   inflating: COMP7710_FP_Dataset/Original/3082.JPG
#   inflating: COMP7710_FP_Dataset/Original/3083.jpg
#   inflating: COMP7710_FP_Dataset/Original/3084.JPG
#   inflating: COMP7710_FP_Dataset/Original/3085.jpg
#   inflating: COMP7710_FP_Dataset/Original/3086.JPG
#   inflating: COMP7710_FP_Dataset/Original/3087.jpg
#   inflating: COMP7710_FP_Dataset/Original/3088.jpg
#   inflating: COMP7710_FP_Dataset/Original/3089.jpg
#   inflating: COMP7710_FP_Dataset/Original/309.jpg
#   inflating: COMP7710_FP_Dataset/Original/3090.JPG
#   inflating: COMP7710_FP_Dataset/Original/3091.jpg
#   inflating: COMP7710_FP_Dataset/Original/3092.jpg
#   inflating: COMP7710_FP_Dataset/Original/3093.JPG
#   inflating: COMP7710_FP_Dataset/Original/3094.jpg
#   inflating: COMP7710_FP_Dataset/Original/3095.JPG
#   inflating: COMP7710_FP_Dataset/Original/3096.jpg
#   inflating: COMP7710_FP_Dataset/Original/3097.JPG
#   inflating: COMP7710_FP_Dataset/Original/3098.jpg
#   inflating: COMP7710_FP_Dataset/Original/3099.jpg
#   inflating: COMP7710_FP_Dataset/Original/31.jpg
#   inflating: COMP7710_FP_Dataset/Original/310.jpg
#   inflating: COMP7710_FP_Dataset/Original/3100.JPG
#   inflating: COMP7710_FP_Dataset/Original/3101.jpg
#   inflating: COMP7710_FP_Dataset/Original/3102.JPG
#   inflating: COMP7710_FP_Dataset/Original/3103.jpg
#   inflating: COMP7710_FP_Dataset/Original/3104.jpg
#   inflating: COMP7710_FP_Dataset/Original/3105.JPG
#   inflating: COMP7710_FP_Dataset/Original/3106.jpg
#   inflating: COMP7710_FP_Dataset/Original/3107.jpg
#   inflating: COMP7710_FP_Dataset/Original/3108.jpg
#   inflating: COMP7710_FP_Dataset/Original/3109.jpg
#   inflating: COMP7710_FP_Dataset/Original/311.jpg
#   inflating: COMP7710_FP_Dataset/Original/3110.JPG
#   inflating: COMP7710_FP_Dataset/Original/3111.jpg
#   inflating: COMP7710_FP_Dataset/Original/3112.JPG
#   inflating: COMP7710_FP_Dataset/Original/3113.jpg
#   inflating: COMP7710_FP_Dataset/Original/3114.JPG
#   inflating: COMP7710_FP_Dataset/Original/3115.jpg
#   inflating: COMP7710_FP_Dataset/Original/3116.JPG
#   inflating: COMP7710_FP_Dataset/Original/3117.jpg
#   inflating: COMP7710_FP_Dataset/Original/3118.JPG
#   inflating: COMP7710_FP_Dataset/Original/3119.jpg
#   inflating: COMP7710_FP_Dataset/Original/312.jpg
#   inflating: COMP7710_FP_Dataset/Original/3120.jpg
#   inflating: COMP7710_FP_Dataset/Original/3121.jpg
#   inflating: COMP7710_FP_Dataset/Original/3122.JPG
#   inflating: COMP7710_FP_Dataset/Original/3123.jpg
#   inflating: COMP7710_FP_Dataset/Original/3124.jpg
#   inflating: COMP7710_FP_Dataset/Original/3125.JPG
#   inflating: COMP7710_FP_Dataset/Original/3126.jpg
#   inflating: COMP7710_FP_Dataset/Original/3127.JPG
#   inflating: COMP7710_FP_Dataset/Original/3128.jpg
#   inflating: COMP7710_FP_Dataset/Original/3129.jpg
#   inflating: COMP7710_FP_Dataset/Original/313.jpg
#   inflating: COMP7710_FP_Dataset/Original/3130.JPG
#   inflating: COMP7710_FP_Dataset/Original/3131.jpg
#   inflating: COMP7710_FP_Dataset/Original/3132.jpg
#   inflating: COMP7710_FP_Dataset/Original/3133.jpg
#   inflating: COMP7710_FP_Dataset/Original/3134.jpg
#   inflating: COMP7710_FP_Dataset/Original/3135.JPG
#   inflating: COMP7710_FP_Dataset/Original/3136.jpg
#   inflating: COMP7710_FP_Dataset/Original/3137.jpg
#   inflating: COMP7710_FP_Dataset/Original/3138.JPG
#   inflating: COMP7710_FP_Dataset/Original/3139.jpg
#   inflating: COMP7710_FP_Dataset/Original/314.jpg
#   inflating: COMP7710_FP_Dataset/Original/3140.JPG
#   inflating: COMP7710_FP_Dataset/Original/3141.jpg
#   inflating: COMP7710_FP_Dataset/Original/3142.jpg
#   inflating: COMP7710_FP_Dataset/Original/3143.jpg
#   inflating: COMP7710_FP_Dataset/Original/3144.JPG
#   inflating: COMP7710_FP_Dataset/Original/3145.jpg
#   inflating: COMP7710_FP_Dataset/Original/3146.jpg
#   inflating: COMP7710_FP_Dataset/Original/3147.JPG
#   inflating: COMP7710_FP_Dataset/Original/3148.jpg
#   inflating: COMP7710_FP_Dataset/Original/3149.jpg
#   inflating: COMP7710_FP_Dataset/Original/315.jpg
#   inflating: COMP7710_FP_Dataset/Original/3150.jpg
#   inflating: COMP7710_FP_Dataset/Original/3151.JPG
#   inflating: COMP7710_FP_Dataset/Original/3152.jpg
#   inflating: COMP7710_FP_Dataset/Original/3153.jpg
#   inflating: COMP7710_FP_Dataset/Original/3154.jpg
#   inflating: COMP7710_FP_Dataset/Original/3155.JPG
#   inflating: COMP7710_FP_Dataset/Original/3156.jpg
#   inflating: COMP7710_FP_Dataset/Original/3157.JPG
#   inflating: COMP7710_FP_Dataset/Original/3158.jpg
#   inflating: COMP7710_FP_Dataset/Original/3159.JPG
#   inflating: COMP7710_FP_Dataset/Original/316.jpg
#   inflating: COMP7710_FP_Dataset/Original/3160.jpg
#   inflating: COMP7710_FP_Dataset/Original/3161.JPG
#   inflating: COMP7710_FP_Dataset/Original/3162.jpg
#   inflating: COMP7710_FP_Dataset/Original/3163.JPG
# ...
#   inflating: COMP7710_FP_Dataset/Original/721.jpg
#   inflating: COMP7710_FP_Dataset/Original/722.jpg
#   inflating: COMP7710_FP_Dataset/Original/723.jpg
#   inflating: COMP7710_FP_Dataset/Original/724.jpg
#   inflating: COMP7710_FP_Dataset/Original/725.jpg
#   inflating: COMP7710_FP_Dataset/Original/726.jpg
#   inflating: COMP7710_FP_Dataset/Original/727.jpg
#   inflating: COMP7710_FP_Dataset/Original/728.jpg
#   inflating: COMP7710_FP_Dataset/Original/729.jpg
#   inflating: COMP7710_FP_Dataset/Original/73.jpg
#   inflating: COMP7710_FP_Dataset/Original/730.jpg
#   inflating: COMP7710_FP_Dataset/Original/731.jpg
#   inflating: COMP7710_FP_Dataset/Original/732.jpg
#   inflating: COMP7710_FP_Dataset/Original/733.jpg
#   inflating: COMP7710_FP_Dataset/Original/734.jpg
#   inflating: COMP7710_FP_Dataset/Original/735.jpg
#   inflating: COMP7710_FP_Dataset/Original/736.jpg
#   inflating: COMP7710_FP_Dataset/Original/737.jpg
#   inflating: COMP7710_FP_Dataset/Original/738.jpg
#   inflating: COMP7710_FP_Dataset/Original/739.jpg
#   inflating: COMP7710_FP_Dataset/Original/74.jpg
#   inflating: COMP7710_FP_Dataset/Original/740.jpg
#   inflating: COMP7710_FP_Dataset/Original/741.jpg
#   inflating: COMP7710_FP_Dataset/Original/742.jpg
#   inflating: COMP7710_FP_Dataset/Original/743.jpg
#   inflating: COMP7710_FP_Dataset/Original/744.jpg
#   inflating: COMP7710_FP_Dataset/Original/745.jpg
#   inflating: COMP7710_FP_Dataset/Original/746.jpg
#   inflating: COMP7710_FP_Dataset/Original/747.jpg
#   inflating: COMP7710_FP_Dataset/Original/748.jpg
#   inflating: COMP7710_FP_Dataset/Original/749.jpg
#   inflating: COMP7710_FP_Dataset/Original/75.jpg
#   inflating: COMP7710_FP_Dataset/Original/750.jpg
#   inflating: COMP7710_FP_Dataset/Original/751.jpg
#   inflating: COMP7710_FP_Dataset/Original/752.jpg
#   inflating: COMP7710_FP_Dataset/Original/753.jpg
#   inflating: COMP7710_FP_Dataset/Original/754.jpg
#   inflating: COMP7710_FP_Dataset/Original/755.jpg
#   inflating: COMP7710_FP_Dataset/Original/756.jpg
#   inflating: COMP7710_FP_Dataset/Original/757.jpg
#   inflating: COMP7710_FP_Dataset/Original/758.jpg
#   inflating: COMP7710_FP_Dataset/Original/759.jpg
#   inflating: COMP7710_FP_Dataset/Original/76.jpg
#   inflating: COMP7710_FP_Dataset/Original/760.jpg
#   inflating: COMP7710_FP_Dataset/Original/761.jpg
#   inflating: COMP7710_FP_Dataset/Original/762.jpg
#   inflating: COMP7710_FP_Dataset/Original/763.jpg
#   inflating: COMP7710_FP_Dataset/Original/764.jpg
#   inflating: COMP7710_FP_Dataset/Original/765.jpg
#   inflating: COMP7710_FP_Dataset/Original/766.jpg
#   inflating: COMP7710_FP_Dataset/Original/767.jpg
#   inflating: COMP7710_FP_Dataset/Original/768.jpg
#   inflating: COMP7710_FP_Dataset/Original/769.jpg
#   inflating: COMP7710_FP_Dataset/Original/77.jpg
#   inflating: COMP7710_FP_Dataset/Original/770.jpg
#   inflating: COMP7710_FP_Dataset/Original/771.jpg
#   inflating: COMP7710_FP_Dataset/Original/772.jpg
#   inflating: COMP7710_FP_Dataset/Original/773.jpg
#   inflating: COMP7710_FP_Dataset/Original/774.jpg
#   inflating: COMP7710_FP_Dataset/Original/775.jpg
#   inflating: COMP7710_FP_Dataset/Original/776.jpg
#   inflating: COMP7710_FP_Dataset/Original/777.jpg
#   inflating: COMP7710_FP_Dataset/Original/778.jpg
#   inflating: COMP7710_FP_Dataset/Original/779.jpg
#   inflating: COMP7710_FP_Dataset/Original/78.jpg
#   inflating: COMP7710_FP_Dataset/Original/780.jpg
#   inflating: COMP7710_FP_Dataset/Original/781.jpg
#   inflating: COMP7710_FP_Dataset/Original/782.jpg
#   inflating: COMP7710_FP_Dataset/Original/783.jpg
#   inflating: COMP7710_FP_Dataset/Original/784.jpg
#   inflating: COMP7710_FP_Dataset/Original/785.jpg
#   inflating: COMP7710_FP_Dataset/Original/786.jpg
#   inflating: COMP7710_FP_Dataset/Original/787.jpg
#   inflating: COMP7710_FP_Dataset/Original/788.jpg
#   inflating: COMP7710_FP_Dataset/Original/789.tif
#   inflating: COMP7710_FP_Dataset/Original/79.jpg
#   inflating: COMP7710_FP_Dataset/Original/790.jpg
#   inflating: COMP7710_FP_Dataset/Original/791.jpg
#   inflating: COMP7710_FP_Dataset/Original/792.jpg
#   inflating: COMP7710_FP_Dataset/Original/793.jpg
#   inflating: COMP7710_FP_Dataset/Original/794.jpg
#   inflating: COMP7710_FP_Dataset/Original/795.jpg
#   inflating: COMP7710_FP_Dataset/Original/796.jpg
#   inflating: COMP7710_FP_Dataset/Original/797.jpg
#   inflating: COMP7710_FP_Dataset/Original/798.jpg
#   inflating: COMP7710_FP_Dataset/Original/799.jpg
#   inflating: COMP7710_FP_Dataset/Original/8.jpg
#   inflating: COMP7710_FP_Dataset/Original/80.jpg
#   inflating: COMP7710_FP_Dataset/Original/800.jpg
#   inflating: COMP7710_FP_Dataset/Original/801.jpg
#   inflating: COMP7710_FP_Dataset/Original/802.jpg
#   inflating: COMP7710_FP_Dataset/Original/803.jpg
#   inflating: COMP7710_FP_Dataset/Original/804.jpg
#   inflating: COMP7710_FP_Dataset/Original/805.jpg
#   inflating: COMP7710_FP_Dataset/Original/806.jpg
#   inflating: COMP7710_FP_Dataset/Original/807.jpg
#   inflating: COMP7710_FP_Dataset/Original/808.jpg
#   inflating: COMP7710_FP_Dataset/Original/809.jpg
#   inflating: COMP7710_FP_Dataset/Original/81.jpg
#   inflating: COMP7710_FP_Dataset/Original/810.jpg
#   inflating: COMP7710_FP_Dataset/Original/811.jpg
#   inflating: COMP7710_FP_Dataset/Original/812.jpg
#   inflating: COMP7710_FP_Dataset/Original/813.jpg
#   inflating: COMP7710_FP_Dataset/Original/814.jpg
#   inflating: COMP7710_FP_Dataset/Original/815.jpg
#   inflating: COMP7710_FP_Dataset/Original/816.jpg
#   inflating: COMP7710_FP_Dataset/Original/817.jpg
#   inflating: COMP7710_FP_Dataset/Original/818.jpg
#   inflating: COMP7710_FP_Dataset/Original/819.jpg
#   inflating: COMP7710_FP_Dataset/Original/82.jpg
#   inflating: COMP7710_FP_Dataset/Original/820.jpg
#   inflating: COMP7710_FP_Dataset/Original/821.jpg
#   inflating: COMP7710_FP_Dataset/Original/822.jpg
#   inflating: COMP7710_FP_Dataset/Original/823.jpg
#   inflating: COMP7710_FP_Dataset/Original/824.jpg
#   inflating: COMP7710_FP_Dataset/Original/825.jpg
#   inflating: COMP7710_FP_Dataset/Original/826.jpg
#   inflating: COMP7710_FP_Dataset/Original/827.jpg
#   inflating: COMP7710_FP_Dataset/Original/828.jpg
#   inflating: COMP7710_FP_Dataset/Original/829.jpg
#   inflating: COMP7710_FP_Dataset/Original/83.jpg
#   inflating: COMP7710_FP_Dataset/Original/830.jpg
#   inflating: COMP7710_FP_Dataset/Original/831.jpg
#   inflating: COMP7710_FP_Dataset/Original/832.jpg
#   inflating: COMP7710_FP_Dataset/Original/833.jpg
#   inflating: COMP7710_FP_Dataset/Original/834.jpg
#   inflating: COMP7710_FP_Dataset/Original/835.jpg
#   inflating: COMP7710_FP_Dataset/Original/836.jpg
#   inflating: COMP7710_FP_Dataset/Original/837.jpg
#   inflating: COMP7710_FP_Dataset/Original/838.jpg
#   inflating: COMP7710_FP_Dataset/Original/839.jpg
#   inflating: COMP7710_FP_Dataset/Original/84.jpg
#   inflating: COMP7710_FP_Dataset/Original/840.jpg
#   inflating: COMP7710_FP_Dataset/Original/841.jpg
#   inflating: COMP7710_FP_Dataset/Original/842.jpg
#   inflating: COMP7710_FP_Dataset/Original/843.jpg
#   inflating: COMP7710_FP_Dataset/Original/844.jpg
#   inflating: COMP7710_FP_Dataset/Original/845.jpg
#   inflating: COMP7710_FP_Dataset/Original/846.jpg
#   inflating: COMP7710_FP_Dataset/Original/847.jpg
#   inflating: COMP7710_FP_Dataset/Original/848.jpg
#   inflating: COMP7710_FP_Dataset/Original/849.jpg
#   inflating: COMP7710_FP_Dataset/Original/85.jpg
#   inflating: COMP7710_FP_Dataset/Original/850.jpg
#   inflating: COMP7710_FP_Dataset/Original/851.jpg
#   inflating: COMP7710_FP_Dataset/Original/852.jpg
#   inflating: COMP7710_FP_Dataset/Original/853.jpg
#   inflating: COMP7710_FP_Dataset/Original/854.jpg
#   inflating: COMP7710_FP_Dataset/Original/855.jpg
#   inflating: COMP7710_FP_Dataset/Original/856.jpg
#   inflating: COMP7710_FP_Dataset/Original/857.jpg
#   inflating: COMP7710_FP_Dataset/Original/858.jpg
#   inflating: COMP7710_FP_Dataset/Original/859.jpg
#   inflating: COMP7710_FP_Dataset/Original/86.jpg
#   inflating: COMP7710_FP_Dataset/Original/860.jpg
#   inflating: COMP7710_FP_Dataset/Original/861.jpg
#   inflating: COMP7710_FP_Dataset/Original/862.jpg
#   inflating: COMP7710_FP_Dataset/Original/863.jpg
#   inflating: COMP7710_FP_Dataset/Original/864.jpg
#   inflating: COMP7710_FP_Dataset/Original/865.jpg
#   inflating: COMP7710_FP_Dataset/Original/866.jpg
#   inflating: COMP7710_FP_Dataset/Original/867.jpg
#   inflating: COMP7710_FP_Dataset/Original/868.jpg
#   inflating: COMP7710_FP_Dataset/Original/869.jpg
#   inflating: COMP7710_FP_Dataset/Original/87.jpg
#   inflating: COMP7710_FP_Dataset/Original/870.jpg
#   inflating: COMP7710_FP_Dataset/Original/871.jpg
#   inflating: COMP7710_FP_Dataset/Original/872.jpg
#   inflating: COMP7710_FP_Dataset/Original/873.jpg
#   inflating: COMP7710_FP_Dataset/Original/874.jpg
#   inflating: COMP7710_FP_Dataset/Original/875.jpg
#   inflating: COMP7710_FP_Dataset/Original/876.jpg
#   inflating: COMP7710_FP_Dataset/Original/877.jpg
#   inflating: COMP7710_FP_Dataset/Original/878.jpg
#   inflating: COMP7710_FP_Dataset/Original/879.jpg
#   inflating: COMP7710_FP_Dataset/Original/88.jpg
#   inflating: COMP7710_FP_Dataset/Original/880.jpg
#   inflating: COMP7710_FP_Dataset/Original/881.jpg
#   inflating: COMP7710_FP_Dataset/Original/882.jpg
#   inflating: COMP7710_FP_Dataset/Original/883.jpg
#   inflating: COMP7710_FP_Dataset/Original/884.jpg
#   inflating: COMP7710_FP_Dataset/Original/885.jpg
#   inflating: COMP7710_FP_Dataset/Original/886.jpg
#   inflating: COMP7710_FP_Dataset/Original/887.jpg
#   inflating: COMP7710_FP_Dataset/Original/888.jpg
#   inflating: COMP7710_FP_Dataset/Original/889.jpg
#   inflating: COMP7710_FP_Dataset/Original/89.jpg
#   inflating: COMP7710_FP_Dataset/Original/890.jpg
#   inflating: COMP7710_FP_Dataset/Original/891.jpg
#   inflating: COMP7710_FP_Dataset/Original/892.jpg
#   inflating: COMP7710_FP_Dataset/Original/893.jpg
#   inflating: COMP7710_FP_Dataset/Original/894.jpg
#   inflating: COMP7710_FP_Dataset/Original/895.jpg
#   inflating: COMP7710_FP_Dataset/Original/896.jpg
#   inflating: COMP7710_FP_Dataset/Original/897.jpg
#   inflating: COMP7710_FP_Dataset/Original/898.jpg
#   inflating: COMP7710_FP_Dataset/Original/899.jpg
#   inflating: COMP7710_FP_Dataset/Original/9.jpg
#   inflating: COMP7710_FP_Dataset/Original/90.jpg
#   inflating: COMP7710_FP_Dataset/Original/900.jpg
#   inflating: COMP7710_FP_Dataset/Original/901.tif
#   inflating: COMP7710_FP_Dataset/Original/902.jpg
#   inflating: COMP7710_FP_Dataset/Original/903.jpg
#   inflating: COMP7710_FP_Dataset/Original/904.jpg
#   inflating: COMP7710_FP_Dataset/Original/905.jpg
#   inflating: COMP7710_FP_Dataset/Original/906.jpg
#   inflating: COMP7710_FP_Dataset/Original/907.jpg
#   inflating: COMP7710_FP_Dataset/Original/908.jpg
#   inflating: COMP7710_FP_Dataset/Original/909.jpg
#   inflating: COMP7710_FP_Dataset/Original/91.jpg
#   inflating: COMP7710_FP_Dataset/Original/910.jpg
#   inflating: COMP7710_FP_Dataset/Original/911.jpg
#   inflating: COMP7710_FP_Dataset/Original/912.jpg
#   inflating: COMP7710_FP_Dataset/Original/913.jpg
#   inflating: COMP7710_FP_Dataset/Original/914.jpg
#   inflating: COMP7710_FP_Dataset/Original/915.jpg
#   inflating: COMP7710_FP_Dataset/Original/916.jpg
#   inflating: COMP7710_FP_Dataset/Original/917.jpg
#   inflating: COMP7710_FP_Dataset/Original/918.jpg
#   inflating: COMP7710_FP_Dataset/Original/919.jpg
#   inflating: COMP7710_FP_Dataset/Original/92.jpg
#   inflating: COMP7710_FP_Dataset/Original/920.jpg
#   inflating: COMP7710_FP_Dataset/Original/921.jpg
#   inflating: COMP7710_FP_Dataset/Original/922.jpg
#   inflating: COMP7710_FP_Dataset/Original/923.jpg
#   inflating: COMP7710_FP_Dataset/Original/924.jpg
#   inflating: COMP7710_FP_Dataset/Original/925.jpg
#   inflating: COMP7710_FP_Dataset/Original/926.jpg
#   inflating: COMP7710_FP_Dataset/Original/927.jpg
#   inflating: COMP7710_FP_Dataset/Original/928.jpg
#   inflating: COMP7710_FP_Dataset/Original/929.jpg
#   inflating: COMP7710_FP_Dataset/Original/93.jpg
#   inflating: COMP7710_FP_Dataset/Original/930.jpg
#   inflating: COMP7710_FP_Dataset/Original/931.jpg
#   inflating: COMP7710_FP_Dataset/Original/932.jpg
#   inflating: COMP7710_FP_Dataset/Original/933.JPG
#   inflating: COMP7710_FP_Dataset/Original/934.jpg
#   inflating: COMP7710_FP_Dataset/Original/935.jpg
#   inflating: COMP7710_FP_Dataset/Original/936.JPG
#   inflating: COMP7710_FP_Dataset/Original/937.JPG
#   inflating: COMP7710_FP_Dataset/Original/938.jpg
#   inflating: COMP7710_FP_Dataset/Original/939.JPG
#   inflating: COMP7710_FP_Dataset/Original/94.jpg
#   inflating: COMP7710_FP_Dataset/Original/940.JPG
#   inflating: COMP7710_FP_Dataset/Original/941.jpg
#   inflating: COMP7710_FP_Dataset/Original/942.jpg
#   inflating: COMP7710_FP_Dataset/Original/943.jpg
#   inflating: COMP7710_FP_Dataset/Original/944.jpg
#   inflating: COMP7710_FP_Dataset/Original/945.jpg
#   inflating: COMP7710_FP_Dataset/Original/946.jpg
#   inflating: COMP7710_FP_Dataset/Original/947.jpg
#   inflating: COMP7710_FP_Dataset/Original/948.jpg
#   inflating: COMP7710_FP_Dataset/Original/949.jpg
#   inflating: COMP7710_FP_Dataset/Original/95.jpg
#   inflating: COMP7710_FP_Dataset/Original/950.jpg
#   inflating: COMP7710_FP_Dataset/Original/951.jpg
#   inflating: COMP7710_FP_Dataset/Original/952.jpg
#   inflating: COMP7710_FP_Dataset/Original/953.jpg
#   inflating: COMP7710_FP_Dataset/Original/954.jpg
#   inflating: COMP7710_FP_Dataset/Original/955.jpg
#   inflating: COMP7710_FP_Dataset/Original/956.jpg
#   inflating: COMP7710_FP_Dataset/Original/957.jpg
#   inflating: COMP7710_FP_Dataset/Original/958.jpg
#   inflating: COMP7710_FP_Dataset/Original/959.jpg
#   inflating: COMP7710_FP_Dataset/Original/96.jpg
#   inflating: COMP7710_FP_Dataset/Original/960.jpg
#   inflating: COMP7710_FP_Dataset/Original/961.jpg
#   inflating: COMP7710_FP_Dataset/Original/962.jpg
#   inflating: COMP7710_FP_Dataset/Original/963.jpg
#   inflating: COMP7710_FP_Dataset/Original/964.jpg
#   inflating: COMP7710_FP_Dataset/Original/965.jpg
#   inflating: COMP7710_FP_Dataset/Original/966.jpg
#   inflating: COMP7710_FP_Dataset/Original/967.jpg
#   inflating: COMP7710_FP_Dataset/Original/968.jpg
#   inflating: COMP7710_FP_Dataset/Original/969.jpg
#   inflating: COMP7710_FP_Dataset/Original/97.jpg
#   inflating: COMP7710_FP_Dataset/Original/970.jpg
#   inflating: COMP7710_FP_Dataset/Original/971.jpg
#   inflating: COMP7710_FP_Dataset/Original/972.jpg
#   inflating: COMP7710_FP_Dataset/Original/973.jpg
#   inflating: COMP7710_FP_Dataset/Original/974.jpg
#   inflating: COMP7710_FP_Dataset/Original/975.jpg
#   inflating: COMP7710_FP_Dataset/Original/976.jpg
#   inflating: COMP7710_FP_Dataset/Original/977.jpg
#   inflating: COMP7710_FP_Dataset/Original/978.jpg
#   inflating: COMP7710_FP_Dataset/Original/979.jpg
#   inflating: COMP7710_FP_Dataset/Original/98.jpg
#   inflating: COMP7710_FP_Dataset/Original/980.jpg
#   inflating: COMP7710_FP_Dataset/Original/981.jpg
#   inflating: COMP7710_FP_Dataset/Original/982.jpg
#   inflating: COMP7710_FP_Dataset/Original/983.jpg
#   inflating: COMP7710_FP_Dataset/Original/984.jpg
#   inflating: COMP7710_FP_Dataset/Original/985.jpg
#   inflating: COMP7710_FP_Dataset/Original/986.jpg
#   inflating: COMP7710_FP_Dataset/Original/987.jpg
#   inflating: COMP7710_FP_Dataset/Original/988.jpg
#   inflating: COMP7710_FP_Dataset/Original/989.jpg
#   inflating: COMP7710_FP_Dataset/Original/99.jpg
#   inflating: COMP7710_FP_Dataset/Original/990.jpg
#   inflating: COMP7710_FP_Dataset/Original/991.jpg
#   inflating: COMP7710_FP_Dataset/Original/992.jpg
#   inflating: COMP7710_FP_Dataset/Original/993.jpg
#   inflating: COMP7710_FP_Dataset/Original/994.jpg
#   inflating: COMP7710_FP_Dataset/Original/995.jpg
#   inflating: COMP7710_FP_Dataset/Original/996.jpg
#   inflating: COMP7710_FP_Dataset/Original/997.jpg
#   inflating: COMP7710_FP_Dataset/Original/998.jpg
#   inflating: COMP7710_FP_Dataset/Original/999.jpg

# %% [markdown]
# ## **Pre-Processing Stage**

# %%
#Apply ELA (Error Level Analysis) to images and generate new folder...
'''
*Note: This function involve in pre-processing utilised AI tools (Google Colab assistance)
       to help in the development process. It opens the original file,
       resaves file with 90% quality and then calculates difference
       between (the 'ELA' part), then saves the image to ELA directory...
'''

def apply_ela(image_path, output_path, quality=90):
    original = Image.open(image_path).convert('RGB')
    temp_path = image_path + '.resaved.jpg'
    original.save(temp_path, 'JPEG', quality=quality)
    resaved = Image.open(temp_path)

    ela_image = ImageChops.difference(original, resaved)
    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    scale = 255.0 / max_diff if max_diff != 0 else 1.0
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    ela_image.save(output_path)
    os.remove(temp_path)

# %%
 # Generating new dataset with ELA applied (AI Assistance for utilising os module for saving/resaving images)
def process_dataset(input_dir, output_dir):
    for label in ['Original', 'Forged']:
        in_path = os.path.join(input_dir, label)
        out_path = os.path.join(output_dir, label)
        for fname in  os.listdir(in_path):
            if fname.lower().endswith(('.jpg', '.jpeg')):
              apply_ela(os.path.join(in_path, fname), #Call to ELA function
              os.path.join(out_path, fname)) #Save new ELA image

process_dataset(data_dir, './ELA_Dataset')

# %% [markdown]
# *Check Length of ELA in Original & Forged Directory*

# %%
original_total = os.listdir('./ELA_Dataset/Original')

forged_total = os.listdir('./ELA_Dataset/Forged')

print(f'Original: {len(original_total)}')
print(f'Forged: {len(forged_total)}')
# Out:
# Original: 6475
# Forged: 2379

# %%
original_total[0:50]
# Out:
# ['3540.jpg',
#  '877.jpg',
#  '5729.jpg',
#  '5746.jpg',
#  '4095.jpg',
#  '1965.jpg',
#  '3873.JPG',
#  '3280.JPG',
#  '2470.jpg',
#  '4557.JPG',
#  '4627.JPG',
#  '2121.jpg',
#  '5770.jpg',
#  '4015.jpg',
#  '5676.JPG',
#  '3370.JPG',
#  '314.jpg',
#  '358.jpg',
#  '3736.JPG',
#  '5349.JPG',
#  '1706.jpg',
#  '4788.JPG',
#  '2859.jpg',
#  '824.jpg',
#  '2695.jpg',
#  '3677.jpg',
#  '296.jpg',
#  '4410.jpg',
#  '2139.jpg',
#  '351.jpg',
#  '685.jpg',
#  '3555.JPG',
#  '2713.jpg',
#  '3167.jpg',
#  '3146.jpg',
#  '2113.jpg',
#  '2491.jpg',
#  '4212.jpg',
#  '3722.jpg',
#  '3772.JPG',
#  '5626.JPG',
#  '3689.jpg',
#  '2147.jpg',
#  '3462.jpg',
#  '1353.jpg',
#  '2793.jpg',
#  '5955.jpg',
#  '5423.JPG',
#  '1220.jpg',
#  '2240.jpg']

# %% [markdown]
# *View an ELA Image vs an original non-ELA Image*

# %%
#View an Image with ELA not applied (original image)...
image = mpimg.imread('COMP7710_FP_Dataset/Original/'+original_total[12])

plt.imshow(image)
plt.show()

# %%
#View a image with ELA applied
image = mpimg.imread('ELA_Dataset/Original/' + original_total[12])

plt.imshow(image)
plt.show()

# %% [markdown]
# *Tampered/fraud Images with and without ELA

# %%
#Show orged/tampered image in non-ELA format

image = mpimg.imread('./COMP7710_FP_Dataset/Forged/'+forged_total[30])
plt.imshow(image)
plt.show()

# %%
#Show fraud/tampered image in ELA format...
image = mpimg.imread('./ELA_Dataset/Forged/'+forged_total[30])
plt.imshow(image)
plt.show()

# %% [markdown]
# Note: Demonstrating same code as above but instead using CASIA 2.0 dataset. You will see the significant improvement
# in quality of images (alternaitve notebook)

# %% [markdown]
# *Take only 2000 original and tampered images to be used in ML models*

# %%
#ELA path
dataset_path="ELA_Dataset/"
path_original_images = 'Original/'
path_tampered_images = 'Forged/'

total_original = os.listdir(dataset_path+path_original_images)[0:2000]
total_tampered = os.listdir(dataset_path+path_tampered_images)[0:2000]
print(f'Length of original images used in model is: {len(total_original)} and length of tampered is {len(total_tampered)}')
# Out:
# Length of original images used in model is: 2000 and length of tampered is 2000

# %% [markdown]
# *Convert the images and labels into a format to store in numpy array...*

# %%
#Label for supervised learning algorithms, this will be used as 'Y' in train_test phase
#Note* This is DIFFERENT for when CNN is applied (image folder pre-decides labels)
original_label = [0] * len(total_original)
tampered_label = [1] * len(total_tampered)

# %%
#Helper function to convert Image to flattened numpy array (AI assistance)
from PIL import Image

def process_image(image_path, size=(128, 128), quality=90):
    # Open and resize image
    ela_image = Image.open(image_path).convert('RGB')
    ela_image = ela_image.resize(size)

    # Convert ELA image to flattened NumPy array
    ela_array = np.array(ela_image)             # Shape: (128, 128, 3)
    flattened = ela_array.flatten()             # Shape: (128*128*3,) → (49,152,)

    return flattened

# %%
features = process_image(dataset_path+path_original_images+total_original[0])
print(features.shape)  # Output: (49152,)
# Out:
# (49152,)

# %%
X = []
#Array of x features (should be 128 * 128 * 3 features for each image)
for image in total_original:
    features = process_image(dataset_path+path_original_images+image)
    X.append(features)
print("Flattened all original images")
for image in total_tampered:
    features = process_image(dataset_path+path_tampered_images+image)
    X.append(features)
print("Falttened all tampered images")
X = np.array(X)
print(f"Shape of X is {X.shape}")
# Out:
# Flattened all original images
# Falttened all tampered images
# Shape of X is (4000, 49152)

# %%
#Array of Y labels
y = original_label + tampered_label
y = np.array(y)

print(f"Shape of y (labels) is {y.shape}")
# Out:
# Shape of y (labels) is (4000,)

# %%
print(f"Any nulls in X...{np.isnan(X).any()}")
print(f"Any nulls in y...{np.isnan(y).any()}")
# Out:
# Any nulls in X...False
# Any nulls in y...False

# %%
print(f"Datatype of X...{X.dtype}")
print(f"Datatype of y...{y.dtype}")
# Out:
# Datatype of X...uint8
# Datatype of y...int64

# %% [markdown]
# ## **Splitting into train-test split**
# *Used for training and testing within the model*

# %%
from sklearn.model_selection import train_test_split

#Will use a train/test split of 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print(X_train.shape[0], "samples in training set")
print(X_test.shape[0], "samples in test set")
# Out:
# 3200 samples in training set
# 800 samples in test set

# %% [markdown]
# ## **Logistic Regression (default)**
# *Logistic regression model with default hyper params*

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score

model_results = {}

''''
Function for testing models using relevant metrics...
(Utilises Tutorial 7 code as base)
'''

def get_model_results(model,X_train,X_test,y_train,y_test):
    #Fit logisitc regression with train data and print train accuracy
    start = time.time()
    model.fit(X_train, y_train)
    end = time.time()

    y_pred = model.predict(X_test)

    results = {
        "fit_time": end - start,
        "training_accuracy": model.score(X_train, y_train)*100,
        "cv_accuracy": cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy').mean() * 100,
        "testing_accuracy": accuracy_score(y_test, y_pred)*100,
        "testing_precision": precision_score(y_test, y_pred)*100,
        "testing_recall": recall_score(y_test, y_pred)*100,
        "f1_score": f1_score(y_test, y_pred)*100,
        "confusion_matrix": confusion_matrix(y_test, y_pred)
    }

    print(f'time taken for fitting: {results["fit_time"]}')
    print(f'Training accuracy: {results["training_accuracy"]}')
    print(f'Average accuracy of cross_val_score: {results["cv_accuracy"]}\n')

    #Get test accuracy, precision and recall
    print("Testing accuracy: ", results['testing_accuracy'])
    print(f'Testing Precision: {results["testing_precision"]}')
    print(f'Testing Recall: {results["testing_recall"]}')
    print(f'f1 Score: {results["f1_score"]}')

    return results

# %%
from sklearn.linear_model import LogisticRegression

default_lr_model = LogisticRegression()

default_lr_model_results = get_model_results(default_lr_model, X_train, X_test, y_train, y_test)
# Out:
# time taken for fitting: 22.274911165237427
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 97.4375
#
# Testing accuracy:  97.625
# Testing Precision: 98.9100817438692
# Testing Recall: 96.03174603174604
# f1 Score: 97.4496644295302

# %%
#Print Confusion matrix for default model
model_results['logistic_regression_default'] = default_lr_model_results
ConfusionMatrixDisplay(default_lr_model_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()

# %% [markdown]
# *Logistic Regression with scaled data...*

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
logistic_regression_scaled = LogisticRegression()

logistic_regression_scaled_results = get_model_results(logistic_regression_scaled, X_train_scaled, X_test_scaled, y_train, y_test)

model_results = {'logistic_regression_scaled': logistic_regression_scaled_results}
# Out:
# time taken for fitting: 7.493511199951172
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 97.24999999999999
#
# Testing accuracy:  97.875
# Testing Precision: 99.45205479452055
# Testing Recall: 96.03174603174604
# f1 Score: 97.71197846567968

# %%
ConfusionMatrixDisplay(logistic_regression_scaled_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()

# %% [markdown]
# # **LDA & PCA Analysis**
# *generating both an LDA and PCA version of the dataset and then applying logistic regression & SVM...*

# %% [markdown]
# *Generate an dimension reduced version of X using LDA and view shape*

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
#Reduce feature space with LDA...
lda_model = LDA()

lda_model.fit(X_train, y_train)

#Generate train and test datasets
X_train_lda = lda_model.transform(X_train)

X_test_lda = lda_model.transform(X_test)

# %%
X_train_lda.shape
# Out:
# (3200, 1)

# %% [markdown]
# *Dimensionaly reduce X using PCA and view shape*

# %%
from sklearn.decomposition import PCA
pca_model = PCA(n_components=0.95)

pca_model.fit(X_train)
print(pca_model.explained_variance_ratio_)
# Out:
# [2.23137267e-01 4.74947580e-02 2.21832734e-02 ... 8.74450525e-05
#  8.74311641e-05 8.73291451e-05]

# %%
X_train_pca = pca_model.transform(X_train)
X_test_pca = pca_model.transform(X_test)
print(f"Shape of X train pca: {X_train_pca.shape}")
# Out:
# Shape of X train pca: (3200, 2084)

# %% [markdown]
# *View cumulative explain variance of PCA with graph...*

# %%
#Found useful graphing function on stack-overflow
# https://stackoverflow.com/questions/53802098/how-to-choose-the-number-of-components-pca-scikitliear
plt.plot(np.cumsum(pca_model.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %% [markdown]
# *View training and testing success of standard logistic regression with PCA and LDA*

# %% [markdown]
# *LDA results...*

# %%
logistic_regression_lda = LogisticRegression()

logistic_regression_lda_results = get_model_results(logistic_regression_lda, X_train_lda, X_test_lda, y_train, y_test)

model_results['logistic_regression_lda'] = logistic_regression_lda_results
# Out:
# time taken for fitting: 0.011247634887695312
# Training accuracy: 98.40625
# Average accuracy of cross_val_score: 98.375
#
# Testing accuracy:  95.875
# Testing Precision: 96.0
# Testing Recall: 95.23809523809523
# f1 Score: 95.61752988047809

# %%
ConfusionMatrixDisplay(logistic_regression_lda_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()

# %% [markdown]
# *PCA Results...*

# %%
logistic_regression_pca = LogisticRegression()

logistic_regression_pca_results = get_model_results(logistic_regression_pca, X_train_pca, X_test_pca, y_train, y_test)

model_results['logistic_regression_pca'] = logistic_regression_pca_results
# Out:
# time taken for fitting: 1.8030617237091064
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 96.81249999999999
#
# Testing accuracy:  97.375
# Testing Precision: 98.9041095890411
# Testing Recall: 95.5026455026455
# f1 Score: 97.1736204576043

# %%
ConfusionMatrixDisplay(logistic_regression_pca_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()

# %% [markdown]
# Handling overfitting of training accuracy on PCA...

# %% [markdown]
# *Reducing PCA components and and seeing how it impacts model...*

# %%
pca_model_2 = PCA(n_components=1000)


X_train_pca_1000 = pca_model_2.fit_transform(X_train)
X_test_pca_1000 = pca_model_2.transform(X_test)

logistic_regression_pca_1000 = LogisticRegression(max_iter = 3000)

logistic_regression_pca_1000_results = get_model_results(logistic_regression_pca_1000, X_train_pca_1000, X_test_pca_1000, y_train, y_test)

model_results['logistic_regression_pca_1000'] = logistic_regression_pca_1000_results
# Out:
# time taken for fitting: 1.9655122756958008
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 96.96875
#
# Testing accuracy:  97.25
# Testing Precision: 98.36956521739131
# Testing Recall: 95.76719576719577
# f1 Score: 97.05093833780161

# %% [markdown]
# *Finding maximum value of c for LDA and PCA*

# %%
#c values to test
def find_c_hyperparam(x_train, y_train):
  c_values = [0.01, 0.1, 1, 10, 100, 1000] # Values of C to check...

  acc_c = []

  for c in c_values:
      lr_model = LogisticRegression(C=c, max_iter = 3000)
      #use cross validation to create train and validation sets out of 5 folds
      scores = cross_val_score(lr_model, x_train, y_train, cv=5, scoring='accuracy')
      acc_c.append(scores.mean())
  print("Best C: ", c_values[np.argmax(acc_c)])

  return c_values[np.argmax(acc_c)]

# %%
start = time.time()
find_c_hyperparam(X_train_lda, y_train)
end = time.time()
print(f'total time to find best c for lda: {end - start}')
# Out:
# Best C:  0.01
# total time to find best c for lda: 0.2626767158508301

# %%
start = time.time()
find_c_hyperparam(X_train_pca_1000, y_train)
end = time.time()
print(f'total time to find best c for pca: {end - start}')
# Out:
# Best C:  1
# total time to find best c for pca: 54.50340509414673

# %% [markdown]
# Testing results for maximised c value for LDA & PCA

# %%
print("LDA improved c value...")


model_lda = LogisticRegression(C=0.01)
res = get_model_results(model_lda, X_train_lda, X_test_lda, y_train, y_test)
# Out:
# LDA improved c value...
# time taken for fitting: 0.004143238067626953
# Training accuracy: 98.40625
# Average accuracy of cross_val_score: 98.40625
#
# Testing accuracy:  95.625
# Testing Precision: 95.49071618037135
# Testing Recall: 95.23809523809523
# f1 Score: 95.36423841059603

# %%
print("PCA improved c value...")

model_pca = LogisticRegression(C=10)
res = get_model_results(model_pca, X_train_pca_1000, X_test_pca_1000, y_train, y_test)
# Out:
# PCA improved c value...
# time taken for fitting: 0.5434205532073975
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 96.9375
#
# Testing accuracy:  97.375
# Testing Precision: 98.3739837398374
# Testing Recall: 96.03174603174604
# f1 Score: 97.18875502008032

# %% [markdown]
# *Using the speed of LDA to maximise parameters*

# %%
from sklearn.model_selection import GridSearchCV
# Function for finding optimal hyper parameters
def optimise(model, param_grid, X_train, y_train):
    grid = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
    grid.fit(X_train, y_train)

    print("Best CV accuracy:", grid.best_score_)
    return grid.best_params_

# %%
#Maximising parameters of LDA...

param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear'],  # safest with both l1 and l2
    'max_iter': [3000]        # ensure convergence
}

lr_lda_maximised = LogisticRegression()

best_lda_lr_params = optimise(lr_lda_maximised, param_grid, X_train_lda, y_train)

print("Best params:", best_lda_lr_params)
# Out:
# Best CV accuracy: 0.9840625
# Best params: {'C': 0.001, 'max_iter': 3000, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
print("LDA Logistic Regression maximised...")


model_lda = LogisticRegression(C=0.01, max_iter=3000, penalty='l1', solver='liblinear')

logistic_regression_lda_maximised_results = get_model_results(model_lda, X_train_lda, X_test_lda, y_train, y_test)

model_results['logistic_regression_lda_maximised'] = logistic_regression_lda_maximised_results
# Out:
# LDA Logistic Regression maximised...
# time taken for fitting: 0.0035772323608398438
# Training accuracy: 98.40625
# Average accuracy of cross_val_score: 98.40625
#
# Testing accuracy:  95.625
# Testing Precision: 94.7780678851175
# Testing Recall: 96.03174603174604
# f1 Score: 95.40078843626807

# %%
print("LDA results with maximising hyperparams...")
ConfusionMatrixDisplay(logistic_regression_lda_maximised_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()
# Out:
# LDA results with maximising hyperparams...

# %% [markdown]
# Maximise parameters for PCA

# %%
#Maximising parameters of PCA...
from sklearn.model_selection import GridSearchCV

#Utilised sklearn docs & GeeksForGeeks docs...
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear'],  # safest with both l1 and l2
    'max_iter': [3000]        # ensure convergence
}

lr_pca_maximised = LogisticRegression()

best_pca_lr_params = optimise(lr_pca_maximised, param_grid, X_train_pca_1000, y_train)

print("Best params:", best_pca_lr_params)
# Out:
# Best CV accuracy: 0.9665624999999999
# Best params: {'C': 0.001, 'max_iter': 3000, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print("PCA Logistic Regression maximised...")


model_pca = LogisticRegression(C=0.001, max_iter=3000, penalty='l1', solver='liblinear')

logistic_regression_pca_maximised_results = get_model_results(model_pca, X_train_pca_1000, X_test_pca_1000, y_train, y_test)

model_results['logistic_regression_pca_maximised'] = logistic_regression_pca_maximised_results
# Out:
# PCA Logistic Regression maximised...
# time taken for fitting: 0.310624361038208
# Training accuracy: 97.375
# Average accuracy of cross_val_score: 96.25
#
# Testing accuracy:  96.5
# Testing Precision: 96.79144385026738
# Testing Recall: 95.76719576719577
# f1 Score: 96.27659574468085

# %%
print("PCA results with maximising hyperparams...")
ConfusionMatrixDisplay(logistic_regression_pca_maximised_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()
# Out:
# PCA results with maximising hyperparams...

# %% [markdown]
# ## **SVM Models**
# *Applying linear & non-linear SVM with PCA & LDA feature reduction dataset *

# %%
from sklearn.svm import SVC

# %% [markdown]
# *Testing Linear kernel with LDA and PCA (default parameters)*

# %%
print("Linear kernel with LDA...")
svc = SVC(kernel='linear')
svc_linear_lda_results = get_model_results(svc, X_train_lda, X_test_lda, y_train, y_test)

model_results['svc_linear_lda'] = svc_linear_lda_results
# Out:
# Linear kernel with LDA...
# time taken for fitting: 0.12273192405700684
# Training accuracy: 98.4375
# Average accuracy of cross_val_score: 98.46875
#
# Testing accuracy:  96.125
# Testing Precision: 96.7654986522911
# Testing Recall: 94.97354497354497
# f1 Score: 95.86114819759679

# %%
print("Linear kernel with PCA...")

svc_linear_pca_results = get_model_results(svc, X_train_pca_1000, X_test_pca_1000, y_train, y_test)

model_results['svc_linear_pca'] = svc_linear_pca_results
# Out:
# Linear kernel with PCA...
# time taken for fitting: 1.5048112869262695
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 96.46874999999999
#
# Testing accuracy:  97.5
# Testing Precision: 98.90710382513662
# Testing Recall: 95.76719576719577
# f1 Score: 97.31182795698925

# %% [markdown]
# *Hyper-parameter tuning for SVC with LDA dataset*

# %%
#Finding optimal kernel for LDA dataset...

param_grid = {
    "kernel": ['linear', 'rbf', 'poly', 'sigmoid']
}

svc = SVC()
best_kernel = optimise(svc, param_grid, X_train_lda, y_train)['kernel']
best_kernel
# Out:
# Best CV accuracy: 0.9846875
# 'linear'

# %%
#Find best c value with optimal kernel...
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100]
}

svc = SVC(kernel = best_kernel)
best_c = optimise(svc, param_grid, X_train_lda, y_train)['C']
best_c
# Out:
# Best CV accuracy: 0.9846875
# 0.01

# %%
#find best degree value with optimal "C" and Kernel...
param_grid = {
    "degree": list(range(2,10,1))
}

svc = SVC(kernel = best_kernel, C = best_c)

best_degree = optimise(svc, param_grid, X_train_lda, y_train)['degree']
best_degree
# Out:
# Best CV accuracy: 0.9846875
# 2

# %%
#Evaluate SVC with optimised parameters using LDA dataset
svc = SVC(kernel=best_kernel, C=best_c, degree=best_degree)
svc_lda_maximised_results = get_model_results(svc, X_train_lda, X_test_lda, y_train, y_test)

model_results['svc_lda_maximised'] = svc_lda_maximised_results
# Out:
# time taken for fitting: 0.09115004539489746
# Training accuracy: 98.46875
# Average accuracy of cross_val_score: 98.46875
#
# Testing accuracy:  96.25
# Testing Precision: 97.28260869565217
# Testing Recall: 94.70899470899471
# f1 Score: 95.97855227882037

# %%
ConfusionMatrixDisplay(svc_lda_maximised_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()

# %% [markdown]
# *Hyper-parameter tuning for SVC with PCA dataset (same process as above)*

# %%
#Optimising PCA dataset with alternate kernel

param_grid = {
    "kernel": ['linear', 'rbf', 'poly', 'sigmoid']
}

svc = SVC()
best_kernel_pca = optimise(svc, param_grid, X_train_pca_1000, y_train)['kernel']
best_kernel_pca
# Out:
# Best CV accuracy: 0.9721875000000001
# 'rbf'

# %%
#Find best c value with optimal kernel...
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100]
}

svc = SVC(kernel = best_kernel_pca)
best_c_pca = optimise(svc, param_grid, X_train_pca_1000, y_train)['C']
best_c_pca
# Out:
# Best CV accuracy: 0.9824999999999999
# 10

# %%
#find best degree value with optimal "C" and Kernel...
param_grid = {
    "degree": list(range(2,10,1))
}

svc = SVC(kernel = best_kernel_pca, C = best_c_pca)

best_degree_pca = optimise(svc, param_grid, X_train_pca_1000, y_train)['degree']
best_degree_pca
# Out:
# Best CV accuracy: 0.9824999999999999
# 2

# %%
#Evaluate SVC with optimised parameters using PCA dataset
svc = SVC(kernel=best_kernel_pca, C=best_c_pca, degree=best_degree_pca)
svc_pca_maximised_results = get_model_results(svc, X_train_pca_1000, X_test_pca_1000, y_train, y_test)

model_results['svc_pca_maximised'] = svc_pca_maximised_results
# Out:
# time taken for fitting: 2.709587812423706
# Training accuracy: 100.0
# Average accuracy of cross_val_score: 98.25
#
# Testing accuracy:  98.25
# Testing Precision: 99.72677595628416
# Testing Recall: 96.56084656084656
# f1 Score: 98.11827956989248

# %%
ConfusionMatrixDisplay(svc_pca_maximised_results['confusion_matrix'], display_labels=['original image','tampered image']).plot()

# %% [markdown]
# # **CNN Model**

# %%
# transform data for pre-normalisation step

# Transform without normalization (for mean/std)
'''
Note: A large portion of code for CNN transformation
      and development was taken from tutorial with slight
      modification to hyper-parameters to better fit/model
      data
'''
temp_transform = transforms.Compose([
    transforms.Grayscale(),
      transforms.RandomRotation(5, fill=(0,)), # Data augmentation
    transforms.RandomCrop(128, padding=2),    # Data augmentation
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# %%
#ImageFolder is a class in pytorch used for loading image data
#That is sorted in folder format (./Forged, ./Original) representing
#their class
dataset = datasets.ImageFolder('ELA_Dataset/', transform=temp_transform)

# %%
#View image entry converted to tensor
dataset[0]
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0078,  ..., 0.0431, 0.0314, 0.0275],
#           [0.0000, 0.0000, 0.0157,  ..., 0.0235, 0.0392, 0.0510],
#           [0.0000, 0.0000, 0.0196,  ..., 0.0039, 0.0275, 0.0392]]]),
#  0)

# %%
# label 0 is Forged, label 1 is Original
print(dataset.class_to_idx)
# Out:
# {'Forged': 0, 'Original': 1}

# %%
# Generate train, val and test splits

# Manually select 2000 jpeg/jpg samples from each class (AI Assistance)
original_indices = [i for i, (path, label) in enumerate(dataset.samples) if dataset.classes[label] == 'Original' and (path.lower().endswith('.jpg') or path.lower().endswith('.jpeg'))][:2000]
forged_indices = [i for i, (path, label) in enumerate(dataset.samples) if dataset.classes[label] == 'Forged' and (path.lower().endswith('.jpg') or path.lower().endswith('.jpeg'))][:2000]

# Combine the indices
subset_indices = original_indices + forged_indices

# Create a Subset of the dataset using the selected indices
subset_dataset = Subset(dataset, subset_indices)

print(f"length of of dataset...{len(subset_dataset)}")
# Out:
# length of of dataset...4000

# %%
train_size = int(0.8 * len(subset_dataset))
test_size = len(subset_dataset) - train_size
train_set, test_set = random_split(subset_dataset, [train_size, test_size])
print(f"length of train set: {len(train_set)}")
print(f"length of test set: {len(test_set)}")
# Out:
# length of train set: 3200
# length of test set: 800

# %%
val_percentage = 0.2

val_size = int(val_percentage * len(train_set))
train_size = len(train_set) - val_size

train_set, val_set = random_split(train_set, [train_size, val_size])

# %%
print(f"Length of train set: {len(train_set)}")
print(f"length of val set: {len(val_set)}")
print(f"length of test set: {len(test_set)}")
# Out:
# Length of train set: 2560
# length of val set: 640
# length of test set: 800

# %%
# Compute mean and std of training data
'''
Note: Function utilised AI assistance throughout development
'''
def compute_mean_std(dataset):
    loader = DataLoader(dataset, batch_size=64, shuffle=False)
    mean = 0.0
    std = 0.0
    total = 0
    for images, _ in loader:
        batch_samples = images.size(0)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)
        total += batch_samples

    mean /= total
    std /= total
    return mean, std

mean, std = compute_mean_std(train_set)

# %%
print('mean: ' + str(mean.tolist()[0]))
print('std: ' + str(std.tolist()[0]))
# Out:
# mean: 0.07579435408115387
# std: 0.05901137739419937

# %%
#Redefine with normalisation

'''
Tutorial code + minor AI assistance for finding helper classes/methods
From this point on, a large portion of code is taken from the tutorial and
modified with hyper-params
'''
train_transform = transforms.Compose([
    transforms.Grayscale(),
    transforms.RandomRotation(5, fill=(0,)), # Data augmentation
    transforms.RandomCrop(128, padding=2),    # Data augmentation
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean.tolist(), std=std.tolist())
])

# Apply to datasets
dataset.transform = train_transform
train_set.dataset.transform = train_transform
val_set.dataset.transform = train_transform
test_set.dataset.transform = train_transform

# %%
#Create interator through dataloaders
BATCH_SIZE = 64

train_iterator = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_iterator = DataLoader(val_set, batch_size=BATCH_SIZE)
test_iterator = DataLoader(test_set, batch_size=BATCH_SIZE)

# %%
#Creating neural network
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


class LeNet(nn.Module):
    def __init__(self, output_dim=10):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1,
                               out_channels=6,
                               kernel_size=5)
        self.conv2 = nn.Conv2d(in_channels=6,
                              out_channels=16,
                            kernel_size=5)


        self.fc1 = nn.Linear(16 * 29 * 29, 120) #For 128 bit image
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, output_dim)

    def forward(self, x):
        # [batch_size, 1, 28, 28]
        x = self.conv1(x)

        # [batch_size, 6,24 ,24]
        x = F.max_pool2d(x, kernel_size=2)
        # [batch_size, 6, 12 ,12]

        x = F.relu(x)
        x = self.conv2(x)
        # [batch_size, 16, 8 ,8]

        x = F.max_pool2d(x, kernel_size=2)
        # [batch_size, 16, 4 ,4]

        x = F.relu(x)

        x = x.view(x.shape[0], -1)
        # [batch_size, 16* 4 * 4]

        x = self.fc1(x)

        x = F.relu(x)

        x = self.fc2(x)

        x = F.relu(x)

        x = self.fc3(x)


        return x

# %%
OUTPUT_DIM = 10

model = LeNet(OUTPUT_DIM)

model
# Out:
# LeNet(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=13456, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 1,628,426 trainable parameters

# %% [markdown]
# ## **Training the CNN model**

# %%
#Define the optimizer
optimizer = optim.Adam(model.parameters())

# %%
#Loss function...
criterion = nn.CrossEntropyLoss()

# %%
#Device on CPU or GPU...
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
model = model.to(device)
criterion = criterion.to(device)

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %%
def train(model, iterator, optimizer, criterion, device):

    epoch_loss, epoch_acc = 0, 0

    model.train()

    for (item, label) in iterator:
        item, label = item.to(device), label.to(device)

        optimizer.zero_grad()

        y_pred = model(item)

        loss = criterion(y_pred, label)

        acc = calculate_accuracy(y_pred, label)

        loss.backward()
        optimizer.step()

        # log

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):

    epoch_loss, epoch_acc = 0, 0

    model.eval()

    with torch.no_grad():
        for (item, label) in iterator:
            item, label = item.to(device), label.to(device)

            y_pred = model(item)

            loss = criterion(y_pred, label)

            acc = calculate_accuracy(y_pred, label)


            # log

            epoch_loss += loss.item()
            epoch_acc += acc.item()
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
EPOCHS = 32

best_valid_loss = float('inf')

train_accs = []
valid_accs = []

for epoch in range(EPOCHS):

    start_time = time.monotonic()

    train_loss, train_acc = train(model, train_iterator, optimizer, criterion, device)
    valid_loss, valid_acc = evaluate(model, val_iterator, criterion, device)

    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'model.pt')

    end_time = time.monotonic()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)

    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')

    train_accs.append(train_acc)
    valid_accs.append(valid_acc)
# Out:
# Epoch: 01 | Epoch Time: 0m 23s
# 	Train Loss: 0.704 | Train Acc: 61.68%
# 	 Val. Loss: 0.562 |  Val. Acc: 66.56%
# Epoch: 02 | Epoch Time: 0m 23s
# 	Train Loss: 0.393 | Train Acc: 81.45%
# 	 Val. Loss: 0.269 |  Val. Acc: 90.62%
# Epoch: 03 | Epoch Time: 0m 23s
# 	Train Loss: 0.224 | Train Acc: 90.43%
# 	 Val. Loss: 0.154 |  Val. Acc: 93.12%
# Epoch: 04 | Epoch Time: 0m 23s
# 	Train Loss: 0.210 | Train Acc: 90.51%
# 	 Val. Loss: 0.197 |  Val. Acc: 91.09%
# Epoch: 05 | Epoch Time: 0m 23s
# 	Train Loss: 0.222 | Train Acc: 90.66%
# 	 Val. Loss: 0.147 |  Val. Acc: 93.59%
# Epoch: 06 | Epoch Time: 0m 22s
# 	Train Loss: 0.171 | Train Acc: 93.01%
# 	 Val. Loss: 0.165 |  Val. Acc: 92.19%
# Epoch: 07 | Epoch Time: 0m 23s
# 	Train Loss: 0.156 | Train Acc: 93.12%
# 	 Val. Loss: 0.113 |  Val. Acc: 93.91%
# Epoch: 08 | Epoch Time: 0m 23s
# 	Train Loss: 0.169 | Train Acc: 92.97%
# 	 Val. Loss: 0.119 |  Val. Acc: 93.91%
# Epoch: 09 | Epoch Time: 0m 22s
# 	Train Loss: 0.152 | Train Acc: 93.98%
# 	 Val. Loss: 0.119 |  Val. Acc: 95.31%
# Epoch: 10 | Epoch Time: 0m 23s
# 	Train Loss: 0.154 | Train Acc: 93.12%
# 	 Val. Loss: 0.121 |  Val. Acc: 95.62%
# Epoch: 11 | Epoch Time: 0m 23s
# 	Train Loss: 0.155 | Train Acc: 93.32%
# 	 Val. Loss: 0.259 |  Val. Acc: 90.62%
# Epoch: 12 | Epoch Time: 0m 23s
# 	Train Loss: 0.136 | Train Acc: 94.06%
# 	 Val. Loss: 0.102 |  Val. Acc: 94.84%
# Epoch: 13 | Epoch Time: 0m 23s
# 	Train Loss: 0.128 | Train Acc: 95.51%
# 	 Val. Loss: 0.099 |  Val. Acc: 95.47%
# Epoch: 14 | Epoch Time: 0m 23s
# 	Train Loss: 0.127 | Train Acc: 95.35%
# 	 Val. Loss: 0.107 |  Val. Acc: 95.47%
# Epoch: 15 | Epoch Time: 0m 23s
# 	Train Loss: 0.135 | Train Acc: 94.26%
# 	 Val. Loss: 0.109 |  Val. Acc: 94.84%
# Epoch: 16 | Epoch Time: 0m 22s
# 	Train Loss: 0.125 | Train Acc: 94.80%
# 	 Val. Loss: 0.097 |  Val. Acc: 95.94%
# Epoch: 17 | Epoch Time: 0m 23s
# 	Train Loss: 0.110 | Train Acc: 95.74%
# 	 Val. Loss: 0.090 |  Val. Acc: 96.41%
# Epoch: 18 | Epoch Time: 0m 24s
# 	Train Loss: 0.107 | Train Acc: 96.05%
# 	 Val. Loss: 0.134 |  Val. Acc: 94.06%
# Epoch: 19 | Epoch Time: 0m 24s
# 	Train Loss: 0.118 | Train Acc: 95.66%
# 	 Val. Loss: 0.079 |  Val. Acc: 96.88%
# Epoch: 20 | Epoch Time: 0m 23s
# 	Train Loss: 0.100 | Train Acc: 95.90%
# 	 Val. Loss: 0.064 |  Val. Acc: 97.19%
# Epoch: 21 | Epoch Time: 0m 24s
# 	Train Loss: 0.095 | Train Acc: 96.45%
# 	 Val. Loss: 0.064 |  Val. Acc: 97.34%
# Epoch: 22 | Epoch Time: 0m 24s
# 	Train Loss: 0.101 | Train Acc: 96.02%
# 	 Val. Loss: 0.064 |  Val. Acc: 97.50%
# Epoch: 23 | Epoch Time: 0m 24s
# 	Train Loss: 0.099 | Train Acc: 96.13%
# 	 Val. Loss: 0.077 |  Val. Acc: 97.19%
# Epoch: 24 | Epoch Time: 0m 23s
# 	Train Loss: 0.087 | Train Acc: 96.84%
# 	 Val. Loss: 0.061 |  Val. Acc: 97.34%
# Epoch: 25 | Epoch Time: 0m 23s
# 	Train Loss: 0.090 | Train Acc: 96.88%
# 	 Val. Loss: 0.088 |  Val. Acc: 96.41%
# Epoch: 26 | Epoch Time: 0m 24s
# 	Train Loss: 0.101 | Train Acc: 96.37%
# 	 Val. Loss: 0.065 |  Val. Acc: 96.88%
# Epoch: 27 | Epoch Time: 0m 24s
# 	Train Loss: 0.085 | Train Acc: 97.11%
# 	 Val. Loss: 0.066 |  Val. Acc: 96.88%
# Epoch: 28 | Epoch Time: 0m 23s
# 	Train Loss: 0.076 | Train Acc: 97.03%
# 	 Val. Loss: 0.055 |  Val. Acc: 97.97%
# Epoch: 29 | Epoch Time: 0m 24s
# 	Train Loss: 0.078 | Train Acc: 96.84%
# 	 Val. Loss: 0.083 |  Val. Acc: 96.09%
# Epoch: 30 | Epoch Time: 0m 24s
# 	Train Loss: 0.085 | Train Acc: 96.84%
# 	 Val. Loss: 0.064 |  Val. Acc: 98.12%
# Epoch: 31 | Epoch Time: 0m 24s
# 	Train Loss: 0.116 | Train Acc: 95.94%
# 	 Val. Loss: 0.062 |  Val. Acc: 98.44%
# Epoch: 32 | Epoch Time: 0m 23s
# 	Train Loss: 0.080 | Train Acc: 97.30%
# 	 Val. Loss: 0.059 |  Val. Acc: 97.66%

# %%
plt.plot(train_accs, label="training accuracy")
plt.plot(valid_accs, label = "validation accuracy")
plt.legend()
plt.show()

# %%
test_loss, test_acc = evaluate(model, test_iterator, criterion, device)

print(f'Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}%')
# Out:
# Test Loss: 0.065 | Test Acc: 97.72%

# %%
# Function to get relevant predictions of model
def get_predictions(model, iterator, device):

    model.eval()

    images = []
    labels = []
    probs = []

    with torch.no_grad():

        for (x, y) in iterator:

            x = x.to(device)

            y_pred = model(x)

            y_prob = F.softmax(y_pred, dim = -1)
            top_pred = y_prob.argmax(1, keepdim = True)

            images.append(x.cpu())
            labels.append(y.cpu())
            probs.append(y_prob.cpu())

    images = torch.cat(images, dim = 0)
    labels = torch.cat(labels, dim = 0)
    probs = torch.cat(probs, dim = 0)

    return images, labels, probs

# %%
#Store the image, labels and probabilities of predictions
images, labels, probs = get_predictions(model, test_iterator, device)

# %%
pred_labels = torch.argmax(probs, 1)

# %%
def plot_confusion_matrix(labels, pred_labels):

    fig = plt.figure(figsize = (10, 10));
    ax = fig.add_subplot(1, 1, 1);
    cm = confusion_matrix(labels, pred_labels);
    cm = ConfusionMatrixDisplay(cm, display_labels = range(2));
    cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
    ax.xaxis.set_ticklabels(['forged', 'original']); ax.yaxis.set_ticklabels(['forged', 'original'])

# %%
plot_confusion_matrix(labels, pred_labels)

# %%
#Get correct predictions
corrects = torch.eq(labels, pred_labels)

# %%
#Get incorrect predictions
incorrect_examples = []

for image, label, prob, correct in zip(images, labels, probs, corrects):
    if not correct:
        incorrect_examples.append((image, label, prob))

incorrect_examples.sort(reverse = True, key = lambda x: torch.max(x[2], dim = 0).values)

# %%
def plot_most_incorrect(incorrect, n_images):

    rows = int(np.sqrt(n_images))
    cols = int(np.sqrt(n_images))

    fig = plt.figure(figsize = (20, 10))
    for i in range(rows*cols):
        ax = fig.add_subplot(rows, cols, i+1)
        image, true_label, probs = incorrect[i]
        true_prob = probs[true_label]
        incorrect_prob, incorrect_label = torch.max(probs, dim = 0)
        ax.imshow(image.view(128, 128).cpu().numpy(), cmap = 'bone')
        ax.set_title(f'true label: {true_label} ({true_prob:.3f})\n' \
                     f'pred label: {incorrect_label} ({incorrect_prob:.3f})')
        ax.axis('off')
    fig.subplots_adjust(hspace=0.5)

# %%
N_IMAGES = 4

plot_most_incorrect(incorrect_examples, N_IMAGES)

# %%
precision = precision_score(labels, pred_labels)
recall = recall_score(labels, pred_labels)

cnn_f1_score = f1_score(labels, pred_labels)

print(f'Test Precision for CNN: {precision:.3f}')
print(f'Test Recall for CNN: {recall:.3f}')
print(f'Test F1 Score for CNN: {cnn_f1_score:.3f}')
# Out:
# Test Precision for CNN: 0.980
# Test Recall for CNN: 0.980
# Test F1 Score for CNN: 0.980

# %%
# Add CNN results to model_results dictionary
model_results['cnn_model'] = {
    "cv_accuracy": max(train_accs) * 100, # Using max training accuracy as CV different in CNN models...
    "testing_accuracy": test_acc * 100,
    "testing_precision": precision * 100,
    "testing_recall": recall * 100,
    "f1_score": cnn_f1_score * 100,
    "confusion_matrix": confusion_matrix(labels, pred_labels)
}

model_results['cnn_model']
# Out:
# {'cv_accuracy': 97.3046875,
#  'testing_accuracy': 97.71634615384616,
#  'testing_precision': 98.0392156862745,
#  'testing_recall': 98.0392156862745,
#  'f1_score': 98.0392156862745,
#  'confusion_matrix': array([[384,   8],
#         [  8, 400]])}

# %% [markdown]
# ## **Comparison**
# *Generating tables and graphs for comparison purposes...*

# %%
import pandas as pd
Data = {
    "Model": [],
    "Train Accuracy": [],
    "Test Accuracy": [],
    "Test Precission": [],
    "Test Recall": [],
    "Test F1 Score": []
}

for name in model_results.keys():
    Data["Model"].append(name)
    Data["Train Accuracy"].append(model_results[name]["cv_accuracy"])
    Data["Test Accuracy"].append(model_results[name]["testing_accuracy"])
    Data["Test Precission"].append(model_results[name]["testing_precision"])
    Data["Test Recall"].append(model_results[name]["testing_recall"])
    Data["Test F1 Score"].append(model_results[name]["f1_score"])

Data = pd.DataFrame(Data)
Data
# Out:
#                                 Model  Train Accuracy  Test Accuracy  \
# 0          logistic_regression_scaled       97.250000      97.875000
# 1             logistic_regression_lda       98.375000      95.875000
# 2             logistic_regression_pca       96.812500      97.375000
# 3        logistic_regression_pca_1000       96.968750      97.250000
# 4   logistic_regression_lda_maximised       98.406250      95.625000
# 5   logistic_regression_pca_maximised       96.250000      96.500000
# 6                      svc_linear_lda       98.468750      96.125000
# 7                      svc_linear_pca       96.468750      97.500000
# 8                   svc_lda_maximised       98.468750      96.250000
# 9                   svc_pca_maximised       98.250000      98.250000
# 10                          cnn_model       97.304688      97.716346
#
#     Test Precission  Test Recall  Test F1 Score
# 0         99.452055    96.031746      97.711978
# 1         96.000000    95.238095      95.617530
# 2         98.904110    95.502646      97.173620
# 3         98.369565    95.767196      97.050938
# 4         94.778068    96.031746      95.400788
# 5         96.791444    95.767196      96.276596
# 6         96.765499    94.973545      95.861148
# 7         98.907104    95.767196      97.311828
# 8         97.282609    94.708995      95.978552
# 9         99.726776    96.560847      98.118280
# 10        98.039216    98.039216      98.039216

# %%
#Note*** The graphs provided made use of Google Collabs built in tools for generating graphs
# From dataframes, these graphs are NOT my own code and are simply visual evaluations of the
# data...

from matplotlib import pyplot as plt
Data.plot(kind='scatter', x='Train Accuracy', y='Test Accuracy', s=32, alpha=.8, figsize=(10, 6))
plt.gca().spines[['top', 'right',]].set_visible(False)

for i, row in Data.iterrows():
    plt.annotate(row['Model'], (row['Train Accuracy'], row['Test Accuracy']))
plt.show()

# %%
metrics = ['Train Accuracy', 'Test Accuracy', 'Test Precission', 'Test Recall', 'Test F1 Score']
bar_width = 0.15
r = np.arange(len(Data['Model']))

plt.figure(figsize=(15, 8))

for i, metric in enumerate(metrics):
    plt.bar(r + i * bar_width, Data[metric], color=f'C{i}', width=bar_width, edgecolor='grey', label=metric)

plt.xlabel('Model', fontweight='bold')
plt.ylabel('Score', fontweight='bold')
plt.xticks(r + bar_width * (len(metrics) - 1) / 2, Data['Model'], rotation=90)
plt.legend(loc='lower left') # Moved legend to upper left
plt.tight_layout()
plt.ylim(90, 100) # Set y-axis limits
plt.show()
